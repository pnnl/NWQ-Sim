# %%
import qiskit
import time
import random
from qiskit import QuantumCircuit, transpile
from qiskit_aer import AerSimulator

def benchmark_qiskit(n_qubits):
    for each in n_qubits:
        circuit = QuantumCircuit(each)
        n_repeats = 100000
        Scount = 100000
        Hcount = 100000
        CXcount = 100000

        for _ in range(n_repeats):
            circuit.h(random.randint(0, each-1))
            num = random.randint(1, each-2)
            pos = random.choice([-1, 1])
            circuit.cx(num, num+pos)
            circuit.s(random.randint(0, each-1)) 
        
        print(circuit.depth())
        simulator = AerSimulator(method='stabilizer')

        start = time.perf_counter()
        result = simulator.run(circuit).result()
        end = time.perf_counter()
        
        print("Time", end - start)
        
        filename = f"/Users/garn195/Project Repositories/NWQ-Sim/stabilizer/sim_bench/qiskit_{each}.txt"
        with open(filename, "w") as file:
            file.write("qiskit\n")
            file.write(f"{end - start}\n")
            file.write(f"{each}\n")
            file.write(f"{Scount}\n")
            file.write(f"{Hcount}\n")
            file.write(f"{CXcount}\n")

n_qubits = [32768]
benchmark_qiskit(n_qubits)
# Out:
# 37
# Time 9.30312093700013

# %%
import qiskit
import time
import random
from qiskit import QuantumCircuit, transpile
from qiskit_aer import AerSimulator

n_qubits = []
n_repeats = 100
CXcount = 0
Scount = 0

for i in range(1, 101, 1):
    n_qubits.append(i * 128)

# Use the Qiskit Aer stabilizer simulator
simulator = AerSimulator(method='stabilizer')

for each in n_qubits:
    # Create the quantum circuit
    circuit = QuantumCircuit(each)

    # Apply Hadamard gates on all but the last qubit
    for _ in range(n_repeats):
        circuit.h(range(each - 1))

    Hcount = each * n_repeats

    print(f"Number of operations in circuit: {circuit.size()}")

    # Transpile for optimization
    transpiled_circuit = transpile(circuit, simulator)

    start = time.perf_counter()
    try:
        start = time.perf_counter()
        result = simulator.run(circuit).result()
        end = time.perf_counter()
    except Exception as e:
        print(f"Simulation failed for {each} qubits: {e}")
        break
    end = time.perf_counter()

    if end - start > 30:
        print("Breaking due to time limit")
        break

    print("Time:", end - start)

    filename = f"/Users/garn195/Project Repositories/NWQ-Sim/stabilizer/sim_bench/qiskit2D_{each}.txt"
    with open(filename, "w") as file:
        file.write("qiskit2D\n")
        file.write(f"{end - start}\n")
        file.write(f"{each}\n")
        file.write(f"{Scount}\n")
        file.write(f"{Hcount}\n")
        file.write(f"{CXcount}\n")
# Out:
# Number of operations in circuit: 12700
# Time: 0.3322621649995199
# Number of operations in circuit: 25500
# Time: 0.8429188860000068
# Number of operations in circuit: 38300
# Time: 1.0809505189999982
# Number of operations in circuit: 51100
# Time: 1.3585908450004354
# Number of operations in circuit: 63900
# Time: 1.6260891700003413
# Number of operations in circuit: 76700
# Time: 1.9947791650001818
# Number of operations in circuit: 89500
# Time: 2.2934208959995885
# Number of operations in circuit: 102300
# Time: 2.5964707149996684
# Number of operations in circuit: 115100
# Time: 2.881554911999956
# Number of operations in circuit: 127900
# Time: 3.221993141999519
# Number of operations in circuit: 140700
# Time: 3.6725551939998695
# Number of operations in circuit: 153500
# Time: 3.8985811430002286
# Number of operations in circuit: 166300
# Time: 4.188727638000273
# Number of operations in circuit: 179100
# Time: 4.488969228000315
# Number of operations in circuit: 191900
# Time: 5.29315950199998
# Number of operations in circuit: 204700
# Time: 5.243161952999799
# Number of operations in circuit: 217500
# Time: 4.8983086309999635
# Number of operations in circuit: 230300
# Time: 5.082112168000094
# Number of operations in circuit: 243100
# Time: 5.400341966000269
# Number of operations in circuit: 255900
# Time: 5.691429624999728
# Number of operations in circuit: 268700
# Time: 6.957356197000081
# Number of operations in circuit: 281500
# Time: 7.544939958000214
# Number of operations in circuit: 294300
# Time: 6.712296720000268
# Number of operations in circuit: 307100
# Time: 7.616246499999761
# Number of operations in circuit: 319900
# Time: 7.270389082999827
# Number of operations in circuit: 332700
# Time: 7.58083771299971
# Number of operations in circuit: 345500
# Time: 7.6929373060002035
# Number of operations in circuit: 358300
# Time: 8.078452575000483
# Number of operations in circuit: 371100
# Time: 8.365969649000363
# Number of operations in circuit: 383900
# Time: 8.670107855999959
# Number of operations in circuit: 396700
# Time: 8.870463324000411
# Number of operations in circuit: 409500
# Time: 9.096258976999707
# Number of operations in circuit: 422300
# Time: 9.467407209999692
# Number of operations in circuit: 435100
# Time: 9.754760871999679
# Number of operations in circuit: 447900
# Time: 10.311128358999667
# Number of operations in circuit: 460700
# Time: 10.411883079999825
# Number of operations in circuit: 473500
# Time: 10.618123678999837
# Number of operations in circuit: 486300
# Time: 11.071346910000102
# Number of operations in circuit: 499100
# Time: 11.328000321000218
# Number of operations in circuit: 511900
# Time: 11.473513205999552
# Number of operations in circuit: 524700
# Time: 11.812667072000295
# Number of operations in circuit: 537500
# Time: 12.268861242999265
# Number of operations in circuit: 550300
# Time: 12.60257423100029
# Number of operations in circuit: 563100
# Time: 12.676423055999294
# Number of operations in circuit: 575900
# Time: 12.980744958000287
# Number of operations in circuit: 588700
# Time: 13.628715316000125
# Number of operations in circuit: 601500
# Time: 14.698357854000278
# Number of operations in circuit: 614300
# Time: 14.735264452999218
# Number of operations in circuit: 627100
# Time: 15.107661222999923
# Number of operations in circuit: 639900
# Time: 15.188036733000445
# Number of operations in circuit: 652700
# Time: 15.328885754000112
# Number of operations in circuit: 665500
# Time: 15.663525246000063
# Number of operations in circuit: 678300
# Time: 16.18828262900024
# Number of operations in circuit: 691100
# Time: 16.41055140000026
# Number of operations in circuit: 703900
# Time: 18.91652146100023
# Number of operations in circuit: 716700
# Time: 18.35834555800011
# Number of operations in circuit: 729500
# Time: 18.68991936600014
# Number of operations in circuit: 742300
# Time: 18.894287428000098
# Number of operations in circuit: 755100
# Time: 19.007538288999967
# Number of operations in circuit: 767900
# Time: 19.19066028100042
# Number of operations in circuit: 780700
# Time: 21.040387781999925
# Number of operations in circuit: 793500
# Time: 19.82904264700028
# Number of operations in circuit: 806300
# Time: 19.892571149000105
# Number of operations in circuit: 819100
# Time: 20.06593844999952
# Number of operations in circuit: 831900
# Time: 20.606557474999136
# Number of operations in circuit: 844700
# Time: 20.769611956000517
# Number of operations in circuit: 857500
# Time: 21.24903798500054
# Number of operations in circuit: 870300
# Time: 21.991861380000046
# Number of operations in circuit: 883100
# Time: 21.888092549999783
# Number of operations in circuit: 895900
# Time: 22.345759517998886
# Number of operations in circuit: 908700
# Time: 22.45417549600097
# Number of operations in circuit: 921500
# Time: 22.793088843000078
# Number of operations in circuit: 934300
# Time: 23.474690786999417
# Number of operations in circuit: 947100
# Time: 23.46449244499854
# Number of operations in circuit: 959900
# Time: 23.623395160000655
# Number of operations in circuit: 972700
# Time: 23.92493473599825
# Number of operations in circuit: 985500
# Time: 24.528380682000716
# Number of operations in circuit: 998300
# Time: 24.716501849999986
# Number of operations in circuit: 1011100
# ---------------------------------------------------------------------------
# CircuitTooWideForTarget                   Traceback (most recent call last)
# Cell In[1], line 31
#      28 print(f"Number of operations in circuit: {circuit.size()}")
#      30 # Transpile for optimization
# ---> 31 transpiled_circuit = transpile(circuit, simulator)
#      33 start = time.perf_counter()
#      34 try:
#
# File ~/Project Repositories/.venv/lib/python3.12/site-packages/qiskit/utils/deprecation.py:184, in deprecate_arg.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     171 @functools.wraps(func)
#     172 def wrapper(*args, **kwargs):
#     173     _maybe_warn_and_rename_kwarg(
#     174         args,
#     175         kwargs,
#    (...)
#     182         predicate=predicate,
#     183     )
# --> 184     return func(*args, **kwargs)
#
# File ~/Project Repositories/.venv/lib/python3.12/site-packages/qiskit/utils/deprecation.py:184, in deprecate_arg.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     171 @functools.wraps(func)
#     172 def wrapper(*args, **kwargs):
#     173     _maybe_warn_and_rename_kwarg(
#     174         args,
#     175         kwargs,
#    (...)
#     182         predicate=predicate,
#     183     )
# --> 184     return func(*args, **kwargs)
#
#     [... skipping similar frames: deprecate_arg.<locals>.decorator.<locals>.wrapper at line 184 (1 times)]
#
# File ~/Project Repositories/.venv/lib/python3.12/site-packages/qiskit/utils/deprecation.py:184, in deprecate_arg.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     171 @functools.wraps(func)
#     172 def wrapper(*args, **kwargs):
#     173     _maybe_warn_and_rename_kwarg(
#     174         args,
#     175         kwargs,
#    (...)
#     182         predicate=predicate,
#     183     )
# --> 184     return func(*args, **kwargs)
#
# File ~/Project Repositories/.venv/lib/python3.12/site-packages/qiskit/compiler/transpiler.py:392, in transpile(circuits, backend, basis_gates, inst_map, coupling_map, backend_properties, initial_layout, layout_method, routing_method, translation_method, scheduling_method, instruction_durations, dt, approximation_degree, timing_constraints, seed_transpiler, optimization_level, callback, output_name, unitary_synthesis_method, unitary_synthesis_plugin_config, target, hls_config, init_method, optimization_method, ignore_backend_supplied_default_methods, num_processes, qubits_initially_zero)
#     390 output_name = _parse_output_name(output_name, circuits)
#     391 coupling_map = _parse_coupling_map(coupling_map)
# --> 392 _check_circuits_coupling_map(circuits, coupling_map, backend)
#     394 # Edge cases require using the old model (loose constraints) instead of building a target,
#     395 # but we don't populate the passmanager config with loose constraints unless it's one of
#     396 # the known edge cases to control the execution path.
#     397 # Filter instruction_durations, timing_constraints, backend_properties and inst_map deprecation
#     398 with warnings.catch_warnings():
#
# File ~/Project Repositories/.venv/lib/python3.12/site-packages/qiskit/compiler/transpiler.py:473, in _check_circuits_coupling_map(circuits, cmap, backend)
#     471 num_qubits = len(circuit.qubits)
#     472 if max_qubits is not None and (num_qubits > max_qubits):
# --> 473     raise CircuitTooWideForTarget(
#     474         f"Number of qubits ({num_qubits}) in {circuit.name} "
#     475         f"is greater than maximum ({max_qubits}) in the coupling_map"
#     476     )
#
# CircuitTooWideForTarget: 'Number of qubits (10112) in circuit-318 is greater than maximum (10000) in the coupling_map'
