# %% [markdown]
# # Demo. Decoder Basics

# %%
import stim
import pymatching
import sys
sys.path.append("../QEC-Codes")  # Adjust the path to import local modules
import numpy as np
from itertools import product
import matplotlib.pyplot as plt
from numpy.typing import NDArray
import pandas as pd
import seaborn as sns
import time
from sklearn.metrics import r2_score

# %%
# QASM export setup (similar to surface_code_ler)
import os, sys, importlib
qasm_dir = "./bb_code72_qasm"
os.makedirs(qasm_dir, exist_ok=True)
# Make sure we can import the conversion utilities
sys.path.insert(0, os.path.abspath("../../../src"))
import noise_util as ns
importlib.reload(ns)
# Out:
# <module 'noise_util' from '/Users/garn195/Library/CloudStorage/OneDrive-PNNL/Project_Repositories/NWQ-Sim/stabilizer/src/noise_util.py'>

# %% [markdown]
# This demo introduces the basics of decoders, focusing on pymatching and BP+OSD.
#
# **What does decoder do?**
# The input is the error information/syndromes/detection events, along with the detector error model that assigns probability/weights to each error mechanism. For each sample, the decoder will return a vector that gives the predictions for the logical errors that have happened (for surface code it's just one value because there is only one logical operator, for general codes it should a vector).

# %% [markdown]
# ### 1. Pymatching for repetition codes

# %% [markdown]
# ### Overall Analysis
# **LER decreases with increasing code distance and decreasing physical error rate (PER).**
# This behavior is consistent with theoretical expectations: as the code distance increases, more physical errors are required to cause a logical error. Similarly, reducing the physical error rate naturally reduces the probability of uncorrectable faults.
#
# <!-- (2) **The break-even PER appears to be ≈ 1, meaning the repetition code always outperforms a single bit.**
# At first glance, this seems to contradict the classical result that repetition codes only outperform a single bit when \( p < 0.5 \) — since majority vote fails above this threshold. However, the classical result is based on **majority vote decoding**, whereas our experiment uses a **matching decoder** (e.g., `pymatching`), which finds the most likely error consistent with the observed syndrome, and can operate effectively even at high error rates. As a result, it can outperform majority vote and maintain logical error suppression for a much wider range of \( p \), even approaching 1.
#
# (3) **The error threshold appears to be >0.5, meaning that increasing the code distance can suppresses the LER even when the PER is large.**
# In standard fault-tolerance theory, a threshold exists below which increasing the code distance improves logical fidelity, and above which larger codes perform worse. Here, because we are using the powerful **matching decoder** on this simple repetition code, the threshold become very large (>0.5). -->

# %% [markdown]
# ### Analysis of LER Scaling
#
# In principle, a QEC code of distance $d$ can correct up to $t = \lfloor \frac{d-1}{2} \rfloor$ errors. In the **ideal** case where all these errors are corrected, the leading-order contribution to the LER should be $p^{t+1}$, where $t + 1 = \lceil \frac{d+1}{2} \rceil$ is the weight of uncorrectable errors. In this case, a log-log plot of LER vs $p$ should produce a straight line with slope $t + 1$.
#
# In realistic scenarios, however, decoding is imperfect: some correctable errors of weight ≤ $t$ may still lead to logical failure due to decoder suboptimality. As a result, the effective scaling exponent becomes **less than** $t + 1$.
#
# Therefore, by fitting the log-log curve $\log(\text{LER})$ vs $ \log(p) $, we can estimate the effective suppression exponent. The **closer the slope is to t+1**, the more effective the decoder is at approaching the ideal case. Conversely, the difference between the slope and the ideal case quantifies suboptimal correction performance under the given noise model and decoding strategy. We can see that when d increases, the leading degrees become closer to t than t+1 and haves the tendency to drop even below t, indicating the fact that it becomes more and more difficult to correct all the errors up to weight t.
#
# The equation $$slope = (d_{eff}+1)/2 $$can give a metric called the "effective distance $d_{eff}$", which should be strictly smaller than the true distance $d$.

# %% [markdown]
# Next, we verify the "exponential suppression" of LER in code distance.

# %%
import sinter
from typing import List

# %% [markdown]
# This time we try to add the 2Q gate error and measurement error as well.

# %% [markdown]
# (1) We kind of see a "threshold behavior": the LER only suppresses as distance increases when PER is below 10.8\%. See where the d = 7 and d = 9 line intersect.
# (2) We also see a "break even" behavior: the LER is belowe PER when p < 10\%, where encoding into repetition code improves the error resilience compared to a bare qubit.

# %% [markdown]
# ### 2. Pymatching for Surface Codes
# We directly use Sinter to streamline the sampling. This time we include the BPOSD decoder as well.

# %%
from bposdd import BPOSD
import BBcode
# from stimbposdd import SinterDecoder_BPOSD, sinter_decoders

# %%
import subprocess
import time

# Compile the C++ code once before the loop
print("Compiling C++ simulator (MPI)...")
# Adjust the path to your C++ file as needed
cpp_file_path = './bb_code_sim.cpp'
executable_path = './bb_code_sim'

compile_command = [
    "mpicxx",  # Use MPI compiler wrapper
    "-std=c++17",
    "-O3",
    "-I../../../../../", # Include for NWQ-Sim headers
    "-DMPI_ENABLED",
    "-o",
    executable_path,
    cpp_file_path
]
try:
    subprocess.run(compile_command, check=True, capture_output=True, text=True)
    print("Compilation successful.")
except subprocess.CalledProcessError as e:
    print("Compilation failed.")
    print("--- stdout ---")
    print(e.stdout)
    print("--- stderr ---")
    print(e.stderr)
# Out:
# Compiling C++ simulator (MPI)...
# Compilation successful.

# %%
# bb_circuit = "bicycle_bivariate_144_12_12_memory_Z"
distance = 6
rounds = 6
SHOTS = 5000000

# %%
#Parameters
tasks = []
T1 = 10 ** -4
T2 = 10 ** -4
# tau = np.array([10**-7, 2*10**-7, 3*10**-7, 4*10**-7, 5*10**-7, 6*10**-7, 7*10**-7, 8*10**-7, 9*10**-7, 10**-6, 1.5*10**-6, 2*10**-6, 3*10**-6, 4*10**-6, 6*10**-6, 7*10**-6, 8*10**-6, 9*10**-6, 10**-5])
tau = np.array([1.05*10**-5, 1.1*10**-5, 1.2*10**-5, 1.3*10**-5, 1.4*10**-5, 1.5*10**-5])

lam = 1/T2 - 1/(2*T1)
p_amp = 1 - np.exp(-tau/T1)
p_phase = 1 - np.exp(-lam*tau)
p_list = (p_amp, p_phase)
base_error = 10**-3

bb_code = BBcode.BBcode(
    n=72, k=12, d=6, m=6, l=6,
    A=[[3, 0], [0, 1], [0, 2]],
    B=[[0, 3], [1, 0], [2, 0]],
    shift=[0, 0],
    f=[[0, 0], [1, 0], [2, 0], [3, 0], [1, 3], [5, 3]],
    g=[[1, 0], [2, 1], [0, 2], [1, 2], [2, 3], [0, 4]],
    h=[[0, 0], [0, 1], [1, 1], [0, 2], [0, 3], [1, 3]],
    alpha=[[0, 0], [0, 1], [2, 1], [2, 5], [3, 2], [4, 0]],
    beta=[[0, 1], [0, 5], [1, 1], [0, 0], [4, 0], [5, 2]],
)

# print(p_amp)
# print(p_phase)
i=0
for p_amp, p_phase in zip(p_amp, p_phase):
    noise_profile = [0,0,0,0]
    bb_circuit = bb_code.build_full_BBcode_circuit(rounds=rounds, noise_profile=noise_profile, observable_type="X", code_capacity=True)

    num_det_meas = bb_circuit.count_determined_measurements()
    num_meas = num_det_meas
    print(len(bb_circuit.flattened()))

    sampler = bb_circuit.compile_detector_sampler()
    det_samples, obs = sampler.sample(1, separate_observables=True, bit_packed=False)
    print(obs)   # should be all True (1) for noiseless prep


    #Generate stim circuit
    model = ns.ErrorModel(bb_circuit)
    model.setting_error('Identity', False, f'DEPOLARIZE1({base_error})')
    model.setting_error('Single_qubit', False, f'DEPOLARIZE1({base_error})')
    model.setting_error('Two_qubit', False, f'DEPOLARIZE2({base_error})')
    model.setting_error('Measurement', True, f'PAULI_CHANNEL_1({p_amp/4}, {p_amp/4}, {((1-np.sqrt((1-p_amp)*(1-p_phase)))/2)-p_amp/4})')
    model.setting_error('Reset', False, f'PAULI_CHANNEL_1({p_amp/4}, {p_amp/4}, {((1-np.sqrt((1-p_amp)*(1-p_phase)))/2)-p_amp/4})')
    stim_circuit = model.generate_noisy_circuit()
    tasks.append(sinter.Task(circuit=stim_circuit, json_metadata={'d': distance, "trial":i}))

    #Generate stabsim circuit   
    model.setting_error('Measurement', True, f'AMPLITUDE_DAMP({p_phase}, {p_amp})')
    model.setting_error('Reset', False, f'AMPLITUDE_DAMP({p_phase}, {p_amp})')
    stab_circuit = model.generate_noisy_circuit()
    qasm_output = ns.stim_to_qasm_with_depolarize_noise(stab_circuit)
    # Inject AMPLITUDE_DAMP around M/RESET in QASM using the model settings
    qasm_output = ns.inject_amplitude_damp(qasm_output, model)
    
    try:
        qasm_path = os.path.join(qasm_dir, f"bb_code_d{distance}_p{i}.qasm")
        with open(qasm_path, "w") as f:
            f.write(qasm_output)
    except Exception as e:
        print(f"Failed to export QASM for p={p_amp}: {e}")
    i+=1

# print(tau)
# Out:
# 722
# [[False False False False False False False False False False False False]]
# 722
# [[False False False False False False False False False False False False]]
# 722
# [[False False False False False False False False False False False False]]
# 722
# [[False False False False False False False False False False False False]]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[35], line 31
#      29 for p_amp, p_phase in zip(p_amp, p_phase):
#      30     noise_profile = [0,0,0,0]
# ---> 31     bb_circuit = bb_code.build_full_BBcode_circuit(rounds=rounds, noise_profile=noise_profile, observable_type="X", code_capacity=True)
#      33     num_det_meas = bb_circuit.count_determined_measurements()
#      34     num_meas = num_det_meas
#
# File ~/Library/CloudStorage/OneDrive-PNNL/Project_Repositories/NWQ-Sim/stabilizer/damping_work/qPLDC-circuits/tomas/BBcode.py:352, in BBcode.build_full_BBcode_circuit(self, rounds, noise_profile, observable_type, code_capacity, prepare_logical_ones)
#     350 # Later rounds
#     351 repeat_circuit.append("TICK")
# --> 352 repeat_circuit += self.build_standard_sm_round(noise_profile, code_capacity=code_capacity)
#     353 repeat_circuit.append_operation("SHIFT_COORDS", [], [0,0,1])
#     354 # Insert detectors
#
# File ~/Library/CloudStorage/OneDrive-PNNL/Project_Repositories/NWQ-Sim/stabilizer/damping_work/qPLDC-circuits/tomas/BBcode.py:222, in BBcode.build_standard_sm_round(self, noise_profile, code_capacity)
#     220         if data_coord in self.data_coords:
#     221             data = self.coord_to_index[data_coord]
# --> 222             circuit.append_operation("CNOT", [anc, data])
#     223             CNOT_pairs += [anc, data]
#     224 if not code_capacity:
#
# KeyboardInterrupt:

# %%
# stim_circuit.diagram('timeline-svg')

# %%
print(len(bb_code.data_coords))

print(bb_code.get_info()['logical_X'])
# Out:
# 72
# [[(0, 1), (2, 1), (4, 1), (6, 1), (2, 7), (10, 7)], [(2, 1), (4, 3), (0, 5), (2, 5), (4, 7), (0, 9), (1, 0), (1, 2), (3, 2), (1, 4), (1, 6), (3, 6)], [(0, 3), (2, 3), (4, 3), (6, 3), (2, 9), (10, 9)], [(2, 3), (4, 5), (0, 7), (2, 7), (4, 9), (0, 11), (1, 2), (1, 4), (3, 4), (1, 6), (1, 8), (3, 8)], [(4, 3), (6, 3), (8, 3), (10, 3), (6, 9), (2, 9)], [(6, 3), (8, 5), (4, 7), (6, 7), (8, 9), (4, 11), (5, 2), (5, 4), (7, 4), (5, 6), (5, 8), (7, 8)], [(4, 11), (6, 11), (8, 11), (10, 11), (6, 5), (2, 5)], [(6, 11), (8, 1), (4, 3), (6, 3), (8, 5), (4, 7), (5, 10), (5, 0), (7, 0), (5, 2), (5, 4), (7, 4)], [(6, 5), (8, 5), (10, 5), (0, 5), (8, 11), (4, 11)], [(8, 5), (10, 7), (6, 9), (8, 9), (10, 11), (6, 1), (7, 4), (7, 6), (9, 6), (7, 8), (7, 10), (9, 10)], [(8, 1), (10, 1), (0, 1), (2, 1), (10, 7), (6, 7)], [(10, 1), (0, 3), (8, 5), (10, 5), (0, 7), (8, 9), (9, 0), (9, 2), (11, 2), (9, 4), (9, 6), (11, 6)]]

# %%
def run_stim_experiment(tasks, shots):
    stim_lers = []
    for i,task in enumerate(tasks):
        print(f"trial={task.json_metadata.get('trial')}")
        print(f"--- Running Stim for task = {i} ---")
        start_time = time.perf_counter()
        collected_stats = sinter.collect(
            num_workers=os.cpu_count()//4,
            tasks=[task],
            decoders=['bposd'],
            max_shots=shots,
            custom_decoders={
                'bposd': BPOSD(
                    max_iter=1000,
                    bp_method="ms",
                    osd_order=10,
                    osd_method="osd_e"
                )
            },
            print_progress=True,
        )
        stim_time = time.perf_counter() - start_time
        stat = collected_stats[0]
        stim_ler = stat.errors / stat.shots
        if stat.errors == 0: stim_ler = 0
        stim_lers.append(stim_ler)
        print(f"Stim LER: {stim_ler}, Sim+Decoding Time: {stim_time:}s\n")
    return stim_lers

# --- Run Stim-only experiment ---
stim_logical_error_rates = run_stim_experiment(tasks, SHOTS)
print("\nStim complete.")
print("Stim LERs:", stim_logical_error_rates)

try:
    results_dir = "./bposd_72_results"
    os.makedirs(results_dir, exist_ok=True)
    p_amp_arr = 1 - np.exp(-tau / T1)
    lam = 1 / T2 - 1 / (2 * T1)
    p_phase_arr = 1 - np.exp(-lam * tau)
    stim_results_path = os.path.join(results_dir, f"stim_bposd_results_d{distance}_shots{SHOTS}.txt")
    with open(stim_results_path, "w") as f:
        f.write("# tau\tp_amp\tp_phase\tstim_ler\n")
        for ta, pa, pp, ler in zip(tau, p_amp_arr, p_phase_arr, stim_logical_error_rates):
            f.write(f"{ta}\t{pa}\t{pp}\t{ler}\n")
    print(f"Saved Stim (BP+OSD) results to {stim_results_path}")
except Exception as e:
    print("Failed to save Stim results:", e)
# Out:
# Starting 112 workers...
# trial=0
# --- Running Stim for task = 0 ---
# 1 tasks left:
#   workers decoder eta shots_left errors_seen json_metadata
#       112   bposd <1m       9999           0 d=6,trial=0
# 1 tasks left:
#   workers decoder eta shots_left errors_seen json_metadata
#       112   bposd <1m       9981           6 d=6,trial=0
# 1 tasks left:
#   workers decoder eta shots_left errors_seen json_metadata
#       112   bposd <1m       9929          41 d=6,trial=0
# 1 tasks left:
#   workers decoder eta shots_left errors_seen json_metadata
#       112   bposd <1m       9895          53 d=6,trial=0
# 1 tasks left:
#   workers decoder eta shots_left errors_seen json_metadata
#       112   bposd <1m       9853          74 d=6,trial=0
# 1 tasks left:
#   workers decoder eta shots_left errors_seen json_metadata
#       112   bposd <1m       9797          99 d=6,trial=0
# 1 tasks left:
#   workers decoder eta shots_left errors_seen json_metadata
#       112   bposd <1m       9715         145 d=6,trial=0
# 1 tasks left:
#   workers decoder eta shots_left errors_seen json_metadata
#       112   bposd <1m       9679         169 d=6,trial=0
# 1 tasks left:
#   workers decoder eta shots_left errors_seen json_metadata
#       112   bposd <1m       9617         201 d=6,trial=0
# 1 tasks left:
#   workers decoder eta shots_left errors_seen json_metadata
#       112   bposd <1m       9561         233 d=6,trial=0
# 1 tasks left:
#   workers decoder eta shots_left errors_seen json_metadata
#       112   bposd <1m       9489         271 d=6,trial=0
# 1 tasks left:
#   workers decoder eta shots_left errors_seen json_metadata
#       112   bposd <1m       9420         304 d=6,trial=0
# 1 tasks left:
#   workers decoder eta shots_left errors_seen json_metadata
#       112   bposd <1m       9286         368 d=6,trial=0
# 1 tasks left:
#   workers decoder eta shots_left errors_seen json_metadata
#       112   bposd <1m       9074         469 d=6,trial=0
# 1 tasks left:
#   workers decoder eta shots_left errors_seen json_metadata
#       112   bposd <1m       8898         570 d=6,trial=0
# 1 tasks left:
#   workers decoder eta shots_left errors_seen json_metadata
#       112   bposd <1m       8773         636 d=6,trial=0
# 1 tasks left:
#   workers decoder eta shots_left errors_seen json_metadata
#       112   bposd <1m       8575         751 d=6,trial=0
# 1 tasks left:
#   workers decoder eta shots_left errors_seen json_metadata
#       112   bposd <1m       8445         820 d=6,trial=0
# 1 tasks left:
#   workers decoder eta shots_left errors_seen json_metadata
#       112   bposd <1m       8314         900 d=6,trial=0
# 1 tasks left:
#   workers decoder eta shots_left errors_seen json_metadata
#       112   bposd <1m       8198         976 d=6,trial=0
# 1 tasks left:
#   workers decoder eta shots_left errors_seen json_metadata
#       112   bposd <1m       8069        1051 d=6,trial=0
# 1 tasks left:
#   workers decoder eta shots_left errors_seen json_metadata
#       112   bposd <1m       7921        1138 d=6,trial=0
# 1 tasks left:
#   workers decoder eta shots_left errors_seen json_metadata
#       112   bposd <1m       7762        1224 d=6,trial=0
# 1 tasks left:
#   workers decoder eta shots_left errors_seen json_metadata
#       112   bposd <1m       7642        1297 d=6,trial=0
# 1 tasks left:
#   workers decoder eta shots_left errors_seen json_metadata
#       112   bposd <1m       7494        1377 d=6,trial=0
# 1 tasks left:
#   workers decoder eta shots_left errors_seen json_metadata
#       112   bposd <1m       7334        1470 d=6,trial=0
# 1 tasks left:
#   workers decoder eta shots_left errors_seen json_metadata
#       112   bposd <1m       7166        1551 d=6,trial=0
# 1 tasks left:
#   workers decoder eta shots_left errors_seen json_metadata
#       112   bposd <1m       7038        1621 d=6,trial=0
# 1 tasks left:
#   workers decoder eta shots_left errors_seen json_metadata
#       112   bposd <1m       6914        1688 d=6,trial=0
# 1 tasks left:
#   workers decoder eta shots_left errors_seen json_metadata
#       112   bposd <1m       6770        1763 d=6,trial=0
# 1 tasks left:
#   workers decoder eta shots_left errors_seen json_metadata
#       112   bposd <1m       6566        1890 d=6,trial=0
# 1 tasks left:
#   workers decoder eta shots_left errors_seen json_metadata
#       112   bposd <1m       6462        1949 d=6,trial=0
# 1 tasks left:
#   workers decoder eta shots_left errors_seen json_metadata
#       112   bposd <1m       6382        2001 d=6,trial=0
# 1 tasks left:
#   workers decoder eta shots_left errors_seen json_metadata
#       112   bposd <1m       6234        2079 d=6,trial=0
# 1 tasks left:
#   workers decoder eta shots_left errors_seen json_metadata
#       112   bposd <1m       6074        2162 d=6,trial=0
# 1 tasks left:
#   workers decoder eta shots_left errors_seen json_metadata
#       112   bposd <1m       5914        2245 d=6,trial=0
# 1 tasks left:
#   workers decoder eta shots_left errors_seen json_metadata
#       112   bposd <1m       5810        2301 d=6,trial=0
# 1 tasks left:
#   workers decoder eta shots_left errors_seen json_metadata
#       112   bposd <1m       5602        2434 d=6,trial=0
# 1 tasks left:
#   workers decoder eta shots_left errors_seen json_metadata
#       112   bposd <1m       5482        2502 d=6,trial=0
# 1 tasks left:
#   workers decoder eta shots_left errors_seen json_metadata
#       112   bposd <1m       5314        2591 d=6,trial=0
# 1 tasks left:
#   workers decoder eta shots_left errors_seen json_metadata
#       112   bposd <1m       5178        2666 d=6,trial=0
# 1 tasks left:
#   workers decoder eta shots_left errors_seen json_metadata
#       112   bposd <1m       5082        2720 d=6,trial=0
# 1 tasks left:
#   workers decoder eta shots_left errors_seen json_metadata
#       112   bposd <1m       4882        2835 d=6,trial=0
# 1 tasks left:
#   workers decoder eta shots_left errors_seen json_metadata
#       112   bposd <1m       4786        2889 d=6,trial=0
# 1 tasks left:
#   workers decoder eta shots_left errors_seen json_metadata
#       112   bposd <1m       4690        2942 d=6,trial=0
# 1 tasks left:
#   workers decoder eta shots_left errors_seen json_metadata
#       112   bposd <1m       4538        3025 d=6,trial=0
# 1 tasks left:
#   workers decoder eta shots_left errors_seen json_metadata
#       112   bposd <1m       4434        3078 d=6,trial=0
# 1 tasks left:
#   workers decoder eta shots_left errors_seen json_metadata
#       112   bposd <1m       4282        3165 d=6,trial=0
# 1 tasks left:
#   workers decoder eta shots_left errors_seen json_metadata
#       112   bposd <1m       4042        3299 d=6,trial=0
# 1 tasks left:
#   workers decoder eta shots_left errors_seen json_metadata
#       112   bposd <1m       3914        3371 d=6,trial=0
# 1 tasks left:
#   workers decoder eta shots_left errors_seen json_metadata
#       112   bposd <1m       3834        3411 d=6,trial=0
# 1 tasks left:
#   workers decoder eta shots_left errors_seen json_metadata
#       112   bposd <1m       3714        3479 d=6,trial=0
# 1 tasks left:
#   workers decoder eta shots_left errors_seen json_metadata
#       112   bposd <1m       3570        3564 d=6,trial=0
# 1 tasks left:
#   workers decoder eta shots_left errors_seen json_metadata
#       112   bposd <1m       3442        3641 d=6,trial=0
# 1 tasks left:
#   workers decoder eta shots_left errors_seen json_metadata
#       112   bposd <1m       3306        3726 d=6,trial=0
# 1 tasks left:
#   workers decoder eta shots_left errors_seen json_metadata
#       112   bposd <1m       3114        3834 d=6,trial=0
# 1 tasks left:
#   workers decoder eta shots_left errors_seen json_metadata
#       112   bposd <1m       3002        3893 d=6,trial=0
# 1 tasks left:
#   workers decoder eta shots_left errors_seen json_metadata
#       112   bposd <1m       2874        3960 d=6,trial=0
# 1 tasks left:
#   workers decoder eta shots_left errors_seen json_metadata
#       112   bposd <1m       2746        4034 d=6,trial=0
# 1 tasks left:
#   workers decoder eta shots_left errors_seen json_metadata
#       112   bposd <1m       2594        4111 d=6,trial=0
# 1 tasks left:
#   workers decoder eta shots_left errors_seen json_metadata
#       112   bposd <1m       2450        4183 d=6,trial=0
# 1 tasks left:
#   workers decoder eta shots_left errors_seen json_metadata
#       112   bposd <1m       2338        4253 d=6,trial=0
# 1 tasks left:
#   workers decoder eta shots_left errors_seen json_metadata
#       112   bposd <1m       2250        4315 d=6,trial=0
# 1 tasks left:
#   workers decoder eta shots_left errors_seen json_metadata
#       112   bposd <1m       2138        4369 d=6,trial=0
# 1 tasks left:
#   workers decoder eta shots_left errors_seen json_metadata
#       112   bposd <1m       2021        4431 d=6,trial=0
# 1 tasks left:
#   workers decoder eta shots_left errors_seen json_metadata
#       112   bposd <1m       1788        4561 d=6,trial=0
# 1 tasks left:
#   workers decoder eta shots_left errors_seen json_metadata
#       112   bposd <1m       1653        4633 d=6,trial=0
# 1 tasks left:
#   workers decoder eta shots_left errors_seen json_metadata
#       112   bposd <1m       1528        4703 d=6,trial=0
# 1 tasks left:
#   workers decoder eta shots_left errors_seen json_metadata
#       112   bposd <1m       1330        4811 d=6,trial=0
# 1 tasks left:
#   workers decoder eta shots_left errors_seen json_metadata
#       112   bposd <1m       1196        4881 d=6,trial=0
# 1 tasks left:
#   workers decoder eta shots_left errors_seen json_metadata
#       112   bposd <1m       1066        4952 d=6,trial=0
# 1 tasks left:
#   workers decoder eta shots_left errors_seen json_metadata
#       112   bposd <1m        887        5059 d=6,trial=0
# 1 tasks left:
#   workers decoder eta shots_left errors_seen json_metadata
#       112   bposd <1m        739        5152 d=6,trial=0
# 1 tasks left:
#   workers decoder eta shots_left errors_seen json_metadata
#       112   bposd <1m        605        5223 d=6,trial=0
# 1 tasks left:
#   workers decoder eta shots_left errors_seen json_metadata
#       112   bposd <1m        347        5363 d=6,trial=0
# 1 tasks left:
#   workers decoder eta shots_left errors_seen json_metadata
#       112   bposd <1m         88        5519 d=6,trial=0
# 1 tasks left:
#   workers decoder eta shots_left errors_seen json_metadata
#       112   bposd <1m          5        5573 d=6,trial=0
# 1 tasks left:
#   workers decoder eta shots_left errors_seen json_metadata
#       112   bposd   ?          0        5578 d=6,trial=0
# Starting 112 workers...
# Stim LER: 0.5578, Sim+Decoding Time: 10.254660964943469s
#
# trial=1
# --- Running Stim for task = 1 ---
# 1 tasks left:
#   workers decoder eta shots_left errors_seen json_metadata
#       112   bposd <1m       9999           0 d=6,trial=1
# 1 tasks left:
#   workers decoder eta shots_left errors_seen json_metadata
#       112   bposd <1m       9985           5 d=6,trial=1
# 1 tasks left:
#   workers decoder eta shots_left errors_seen json_metadata
#       112   bposd <1m       9941          34 d=6,trial=1
# 1 tasks left:
#   workers decoder eta shots_left errors_seen json_metadata
#       112   bposd <1m       9904          59 d=6,trial=1
# 1 tasks left:
#   workers decoder eta shots_left errors_seen json_metadata
#       112   bposd <1m       9871          76 d=6,trial=1
# 1 tasks left:
#   workers decoder eta shots_left errors_seen json_metadata
#       112   bposd <1m       9799         116 d=6,trial=1
# 1 tasks left:
#   workers decoder eta shots_left errors_seen json_metadata
#       112   bposd <1m       9689         189 d=6,trial=1
# 1 tasks left:
#   workers decoder eta shots_left errors_seen json_metadata
#       112   bposd <1m       9631         232 d=6,trial=1
# 1 tasks left:
#   workers decoder eta shots_left errors_seen json_metadata
#       112   bposd <1m       9559         274 d=6,trial=1
# 1 tasks left:
#   workers decoder eta shots_left errors_seen json_metadata
#       112   bposd <1m       9503         304 d=6,trial=1
# 1 tasks left:
#   workers decoder eta shots_left errors_seen json_metadata
#       112   bposd <1m       9439         342 d=6,trial=1
# 1 tasks left:
#   workers decoder eta shots_left errors_seen json_metadata
#       112   bposd <1m       9355         401 d=6,trial=1
# 1 tasks left:
#   workers decoder eta shots_left errors_seen json_metadata
#       112   bposd <1m       9267         459 d=6,trial=1
# 1 tasks left:
#   workers decoder eta shots_left errors_seen json_metadata
#       112   bposd <1m       9163         531 d=6,trial=1
# 1 tasks left:
#   workers decoder eta shots_left errors_seen json_metadata
#       112   bposd <1m       9054         597 d=6,trial=1
# 1 tasks left:
#   workers decoder eta shots_left errors_seen json_metadata
#       112   bposd <1m       8932         664 d=6,trial=1
# 1 tasks left:
#   workers decoder eta shots_left errors_seen json_metadata
#       112   bposd <1m       8786         760 d=6,trial=1
# 1 tasks left:
#   workers decoder eta shots_left errors_seen json_metadata
#       112   bposd <1m       8537         925 d=6,trial=1
# 1 tasks left:
#   workers decoder eta shots_left errors_seen json_metadata
#       112   bposd <1m       8409        1009 d=6,trial=1
# 1 tasks left:
#   workers decoder eta shots_left errors_seen json_metadata
#       112   bposd <1m       8312        1074 d=6,trial=1
# 1 tasks left:
#   workers decoder eta shots_left errors_seen json_metadata
#       112   bposd <1m       8200        1152 d=6,trial=1
# 1 tasks left:
#   workers decoder eta shots_left errors_seen json_metadata
#       112   bposd <1m       8071        1236 d=6,trial=1
# 1 tasks left:
#   workers decoder eta shots_left errors_seen json_metadata
#       112   bposd <1m       7975        1298 d=6,trial=1
# 1 tasks left:
#   workers decoder eta shots_left errors_seen json_metadata
#       112   bposd <1m       7813        1401 d=6,trial=1
# 1 tasks left:
#   workers decoder eta shots_left errors_seen json_metadata
#       112   bposd <1m       7693        1475 d=6,trial=1
# 1 tasks left:
#   workers decoder eta shots_left errors_seen json_metadata
#       112   bposd <1m       7537        1581 d=6,trial=1
# 1 tasks left:
#   workers decoder eta shots_left errors_seen json_metadata
#       112   bposd <1m       7441        1640 d=6,trial=1
# 1 tasks left:
#   workers decoder eta shots_left errors_seen json_metadata
#       112   bposd <1m       7337        1705 d=6,trial=1
# 1 tasks left:
#   workers decoder eta shots_left errors_seen json_metadata
#       112   bposd <1m       7225        1779 d=6,trial=1
# 1 tasks left:
#   workers decoder eta shots_left errors_seen json_metadata
#       112   bposd <1m       7109        1853 d=6,trial=1
# 1 tasks left:
#   workers decoder eta shots_left errors_seen json_metadata
#       112   bposd <1m       6985        1938 d=6,trial=1
# 1 tasks left:
#   workers decoder eta shots_left errors_seen json_metadata
#       112   bposd <1m       6877        2005 d=6,trial=1
# 1 tasks left:
#   workers decoder eta shots_left errors_seen json_metadata
#       112   bposd <1m       6737        2099 d=6,trial=1
# 1 tasks left:
#   workers decoder eta shots_left errors_seen json_metadata
#       112   bposd <1m       6621        2176 d=6,trial=1
# 1 tasks left:
#   workers decoder eta shots_left errors_seen json_metadata
#       112   bposd <1m       6485        2257 d=6,trial=1
# 1 tasks left:
#   workers decoder eta shots_left errors_seen json_metadata
#       112   bposd <1m       6389        2316 d=6,trial=1
# 1 tasks left:
#   workers decoder eta shots_left errors_seen json_metadata
#       112   bposd <1m       6277        2380 d=6,trial=1
# 1 tasks left:
#   workers decoder eta shots_left errors_seen json_metadata
#       112   bposd <1m       6117        2484 d=6,trial=1
# 1 tasks left:
#   workers decoder eta shots_left errors_seen json_metadata
#       112   bposd <1m       6029        2543 d=6,trial=1
# 1 tasks left:
#   workers decoder eta shots_left errors_seen json_metadata
#       112   bposd <1m       5847        2662 d=6,trial=1
# 1 tasks left:
#   workers decoder eta shots_left errors_seen json_metadata
#       112   bposd <1m       5719        2739 d=6,trial=1
# 1 tasks left:
#   workers decoder eta shots_left errors_seen json_metadata
#       112   bposd <1m       5647        2786 d=6,trial=1
# 1 tasks left:
#   workers decoder eta shots_left errors_seen json_metadata
#       112   bposd <1m       5527        2854 d=6,trial=1
# 1 tasks left:
#   workers decoder eta shots_left errors_seen json_metadata
#       112   bposd <1m       5371        2945 d=6,trial=1
# 1 tasks left:
#   workers decoder eta shots_left errors_seen json_metadata
#       112   bposd <1m       5223        3033 d=6,trial=1
# 1 tasks left:
#   workers decoder eta shots_left errors_seen json_metadata
#       112   bposd <1m       5143        3082 d=6,trial=1
# 1 tasks left:
#   workers decoder eta shots_left errors_seen json_metadata
#       112   bposd <1m       4967        3196 d=6,trial=1
# 1 tasks left:
#   workers decoder eta shots_left errors_seen json_metadata
#       112   bposd <1m       4863        3260 d=6,trial=1
# 1 tasks left:
#   workers decoder eta shots_left errors_seen json_metadata
#       112   bposd <1m       4763        3319 d=6,trial=1
# 1 tasks left:
#   workers decoder eta shots_left errors_seen json_metadata
#       112   bposd <1m       4627        3409 d=6,trial=1
# 1 tasks left:
#   workers decoder eta shots_left errors_seen json_metadata
#       112   bposd <1m       4491        3492 d=6,trial=1
# 1 tasks left:
#   workers decoder eta shots_left errors_seen json_metadata
#       112   bposd <1m       4363        3573 d=6,trial=1
# 1 tasks left:
#   workers decoder eta shots_left errors_seen json_metadata
#       112   bposd <1m       4243        3657 d=6,trial=1
# 1 tasks left:
#   workers decoder eta shots_left errors_seen json_metadata
#       112   bposd <1m       4171        3701 d=6,trial=1
# 1 tasks left:
#   workers decoder eta shots_left errors_seen json_metadata
#       112   bposd <1m       4051        3780 d=6,trial=1
# 1 tasks left:
#   workers decoder eta shots_left errors_seen json_metadata
#       112   bposd <1m       3923        3859 d=6,trial=1
# 1 tasks left:
#   workers decoder eta shots_left errors_seen json_metadata
#       112   bposd <1m       3747        3969 d=6,trial=1
# 1 tasks left:
#   workers decoder eta shots_left errors_seen json_metadata
#       112   bposd <1m       3611        4054 d=6,trial=1
# 1 tasks left:
#   workers decoder eta shots_left errors_seen json_metadata
#       112   bposd <1m       3459        4146 d=6,trial=1
# 1 tasks left:
#   workers decoder eta shots_left errors_seen json_metadata
#       112   bposd <1m       3395        4186 d=6,trial=1
# 1 tasks left:
#   workers decoder eta shots_left errors_seen json_metadata
#       112   bposd <1m       3307        4236 d=6,trial=1
# 1 tasks left:
#   workers decoder eta shots_left errors_seen json_metadata
#       112   bposd <1m       3163        4319 d=6,trial=1
# 1 tasks left:
#   workers decoder eta shots_left errors_seen json_metadata
#       112   bposd <1m       3067        4378 d=6,trial=1
# 1 tasks left:
#   workers decoder eta shots_left errors_seen json_metadata
#       112   bposd <1m       2923        4470 d=6,trial=1
# 1 tasks left:
#   workers decoder eta shots_left errors_seen json_metadata
#       112   bposd <1m       2707        4611 d=6,trial=1
# 1 tasks left:
#   workers decoder eta shots_left errors_seen json_metadata
#       112   bposd <1m       2635        4668 d=6,trial=1
# 1 tasks left:
#   workers decoder eta shots_left errors_seen json_metadata
#       112   bposd <1m       2531        4735 d=6,trial=1
# 1 tasks left:
#   workers decoder eta shots_left errors_seen json_metadata
#       112   bposd <1m       2403        4825 d=6,trial=1
# 1 tasks left:
#   workers decoder eta shots_left errors_seen json_metadata
#       112   bposd <1m       2291        4891 d=6,trial=1
# 1 tasks left:
#   workers decoder eta shots_left errors_seen json_metadata
#       112   bposd <1m       2155        4970 d=6,trial=1
# 1 tasks left:
#   workers decoder eta shots_left errors_seen json_metadata
#       112   bposd <1m       2027        5048 d=6,trial=1
# 1 tasks left:
#   workers decoder eta shots_left errors_seen json_metadata
#       112   bposd <1m       1954        5092 d=6,trial=1
# 1 tasks left:
#   workers decoder eta shots_left errors_seen json_metadata
#       112   bposd <1m       1826        5178 d=6,trial=1
# 1 tasks left:
#   workers decoder eta shots_left errors_seen json_metadata
#       112   bposd <1m       1649        5288 d=6,trial=1
# 1 tasks left:
#   workers decoder eta shots_left errors_seen json_metadata
#       112   bposd <1m       1577        5332 d=6,trial=1
# 1 tasks left:
#   workers decoder eta shots_left errors_seen json_metadata
#       112   bposd <1m       1462        5407 d=6,trial=1
# 1 tasks left:
#   workers decoder eta shots_left errors_seen json_metadata
#       112   bposd <1m       1347        5475 d=6,trial=1
# 1 tasks left:
#   workers decoder eta shots_left errors_seen json_metadata
#       112   bposd <1m       1256        5529 d=6,trial=1
# 1 tasks left:
#   workers decoder eta shots_left errors_seen json_metadata
#       112   bposd <1m       1109        5627 d=6,trial=1
# 1 tasks left:
#   workers decoder eta shots_left errors_seen json_metadata
#       112   bposd <1m        949        5725 d=6,trial=1
# 1 tasks left:
#   workers decoder eta shots_left errors_seen json_metadata
#       112   bposd <1m        810        5815 d=6,trial=1
# 1 tasks left:
#   workers decoder eta shots_left errors_seen json_metadata
#       112   bposd <1m        667        5904 d=6,trial=1
# 1 tasks left:
#   workers decoder eta shots_left errors_seen json_metadata
#       112   bposd <1m        461        6036 d=6,trial=1
# 1 tasks left:
#   workers decoder eta shots_left errors_seen json_metadata
#       112   bposd <1m        284        6154 d=6,trial=1
# 1 tasks left:
#   workers decoder eta shots_left errors_seen json_metadata
#       112   bposd <1m         88        6293 d=6,trial=1
# 1 tasks left:
#   workers decoder eta shots_left errors_seen json_metadata
#       112   bposd <1m         26        6331 d=6,trial=1
# 1 tasks left:
#   workers decoder eta shots_left errors_seen json_metadata
#       112   bposd <1m         25        6332 d=6,trial=1
# 1 tasks left:
#   workers decoder eta shots_left errors_seen json_metadata
#       112   bposd   ?          0        6351 d=6,trial=1
# Starting 112 workers...
# Stim LER: 0.6351, Sim+Decoding Time: 11.035685689887032s
#
# trial=2
# --- Running Stim for task = 2 ---
# 1 tasks left:
#   workers decoder eta shots_left errors_seen json_metadata
#       112   bposd <1m       9999           0 d=6,trial=2
# 1 tasks left:
#   workers decoder eta shots_left errors_seen json_metadata
#       112   bposd <1m       9973          12 d=6,trial=2
# 1 tasks left:
#   workers decoder eta shots_left errors_seen json_metadata
#       112   bposd <1m       9929          52 d=6,trial=2
# 1 tasks left:
#   workers decoder eta shots_left errors_seen json_metadata
#       112   bposd <1m       9885          88 d=6,trial=2
# 1 tasks left:
#   workers decoder eta shots_left errors_seen json_metadata
#       112   bposd <1m       9865          98 d=6,trial=2
# 1 tasks left:
#   workers decoder eta shots_left errors_seen json_metadata
#       112   bposd <1m       9793         149 d=6,trial=2
# 1 tasks left:
#   workers decoder eta shots_left errors_seen json_metadata
#       112   bposd <1m       9705         214 d=6,trial=2
# 1 tasks left:
#   workers decoder eta shots_left errors_seen json_metadata
#       112   bposd <1m       9645         259 d=6,trial=2
# 1 tasks left:
#   workers decoder eta shots_left errors_seen json_metadata
#       112   bposd <1m       9601         295 d=6,trial=2
# 1 tasks left:
#   workers decoder eta shots_left errors_seen json_metadata
#       112   bposd <1m       9551         330 d=6,trial=2
# 1 tasks left:
#   workers decoder eta shots_left errors_seen json_metadata
#       112   bposd <1m       9459         403 d=6,trial=2
# 1 tasks left:
#   workers decoder eta shots_left errors_seen json_metadata
#       112   bposd <1m       9369         474 d=6,trial=2
# 1 tasks left:
#   workers decoder eta shots_left errors_seen json_metadata
#       112   bposd <1m       9293         535 d=6,trial=2
# 1 tasks left:
#   workers decoder eta shots_left errors_seen json_metadata
#       112   bposd <1m       9217         593 d=6,trial=2
# 1 tasks left:
#   workers decoder eta shots_left errors_seen json_metadata
#       112   bposd <1m       9092         687 d=6,trial=2
# 1 tasks left:
#   workers decoder eta shots_left errors_seen json_metadata
#       112   bposd <1m       9034         731 d=6,trial=2
# 1 tasks left:
#   workers decoder eta shots_left errors_seen json_metadata
#       112   bposd <1m       8926         820 d=6,trial=2
# 1 tasks left:
#   workers decoder eta shots_left errors_seen json_metadata
#       112   bposd <1m       8793         924 d=6,trial=2
# 1 tasks left:
#   workers decoder eta shots_left errors_seen json_metadata
#       112   bposd <1m       8682        1004 d=6,trial=2
# 1 tasks left:
#   workers decoder eta shots_left errors_seen json_metadata
#       112   bposd <1m       8517        1130 d=6,trial=2
# 1 tasks left:
#   workers decoder eta shots_left errors_seen json_metadata
#       112   bposd <1m       8409        1216 d=6,trial=2
# 1 tasks left:
#   workers decoder eta shots_left errors_seen json_metadata
#       112   bposd <1m       8305        1302 d=6,trial=2
# 1 tasks left:
#   workers decoder eta shots_left errors_seen json_metadata
#       112   bposd <1m       8141        1434 d=6,trial=2
# 1 tasks left:
#   workers decoder eta shots_left errors_seen json_metadata
#       112   bposd <1m       8061        1504 d=6,trial=2
# 1 tasks left:
#   workers decoder eta shots_left errors_seen json_metadata
#       112   bposd <1m       8001        1543 d=6,trial=2
# 1 tasks left:
#   workers decoder eta shots_left errors_seen json_metadata
#       112   bposd <1m       7925        1599 d=6,trial=2
# 1 tasks left:
#   workers decoder eta shots_left errors_seen json_metadata
#       112   bposd <1m       7801        1693 d=6,trial=2
# 1 tasks left:
#   workers decoder eta shots_left errors_seen json_metadata
#       112   bposd <1m       7689        1782 d=6,trial=2
# 1 tasks left:
#   workers decoder eta shots_left errors_seen json_metadata
#       112   bposd <1m       7581        1863 d=6,trial=2
# 1 tasks left:
#   workers decoder eta shots_left errors_seen json_metadata
#       112   bposd <1m       7461        1953 d=6,trial=2
# 1 tasks left:
#   workers decoder eta shots_left errors_seen json_metadata
#       112   bposd <1m       7381        2009 d=6,trial=2
# 1 tasks left:
#   workers decoder eta shots_left errors_seen json_metadata
#       112   bposd <1m       7289        2076 d=6,trial=2
# 1 tasks left:
#   workers decoder eta shots_left errors_seen json_metadata
#       112   bposd <1m       7221        2131 d=6,trial=2
# 1 tasks left:
#   workers decoder eta shots_left errors_seen json_metadata
#       112   bposd <1m       7113        2210 d=6,trial=2
# 1 tasks left:
#   workers decoder eta shots_left errors_seen json_metadata
#       112   bposd <1m       6997        2290 d=6,trial=2
# 1 tasks left:
#   workers decoder eta shots_left errors_seen json_metadata
#       112   bposd <1m       6861        2386 d=6,trial=2
# 1 tasks left:
#   workers decoder eta shots_left errors_seen json_metadata
#       112   bposd <1m       6761        2464 d=6,trial=2
# 1 tasks left:
#   workers decoder eta shots_left errors_seen json_metadata
#       112   bposd <1m       6669        2537 d=6,trial=2
# 1 tasks left:
#   workers decoder eta shots_left errors_seen json_metadata
#       112   bposd <1m       6577        2615 d=6,trial=2
# 1 tasks left:
#   workers decoder eta shots_left errors_seen json_metadata
#       112   bposd <1m       6497        2673 d=6,trial=2
# 1 tasks left:
#   workers decoder eta shots_left errors_seen json_metadata
#       112   bposd <1m       6353        2781 d=6,trial=2
# 1 tasks left:
#   workers decoder eta shots_left errors_seen json_metadata
#       112   bposd <1m       6289        2834 d=6,trial=2
# 1 tasks left:
#   workers decoder eta shots_left errors_seen json_metadata
#       112   bposd <1m       6229        2877 d=6,trial=2
# 1 tasks left:
#   workers decoder eta shots_left errors_seen json_metadata
#       112   bposd <1m       6121        2963 d=6,trial=2
# 1 tasks left:
#   workers decoder eta shots_left errors_seen json_metadata
#       112   bposd <1m       5989        3064 d=6,trial=2
# 1 tasks left:
#   workers decoder eta shots_left errors_seen json_metadata
#       112   bposd <1m       5881        3151 d=6,trial=2
# 1 tasks left:
#   workers decoder eta shots_left errors_seen json_metadata
#       112   bposd <1m       5785        3228 d=6,trial=2
# 1 tasks left:
#   workers decoder eta shots_left errors_seen json_metadata
#       112   bposd <1m       5693        3302 d=6,trial=2
# 1 tasks left:
#   workers decoder eta shots_left errors_seen json_metadata
#       112   bposd <1m       5585        3384 d=6,trial=2
# 1 tasks left:
#   workers decoder eta shots_left errors_seen json_metadata
#       112   bposd <1m       5505        3448 d=6,trial=2
# 1 tasks left:
#   workers decoder eta shots_left errors_seen json_metadata
#       112   bposd <1m       5429        3506 d=6,trial=2
# 1 tasks left:
#   workers decoder eta shots_left errors_seen json_metadata
#       112   bposd <1m       5349        3569 d=6,trial=2
# 1 tasks left:
#   workers decoder eta shots_left errors_seen json_metadata
#       112   bposd <1m       5221        3675 d=6,trial=2
# 1 tasks left:
#   workers decoder eta shots_left errors_seen json_metadata
#       112   bposd <1m       5161        3723 d=6,trial=2
# 1 tasks left:
#   workers decoder eta shots_left errors_seen json_metadata
#       112   bposd <1m       5029        3829 d=6,trial=2
# 1 tasks left:
#   workers decoder eta shots_left errors_seen json_metadata
#       112   bposd <1m       4917        3922 d=6,trial=2
# 1 tasks left:
#   workers decoder eta shots_left errors_seen json_metadata
#       112   bposd <1m       4857        3968 d=6,trial=2
# 1 tasks left:
#   workers decoder eta shots_left errors_seen json_metadata
#       112   bposd <1m       4773        4025 d=6,trial=2
# 1 tasks left:
#   workers decoder eta shots_left errors_seen json_metadata
#       112   bposd <1m       4677        4095 d=6,trial=2
# 1 tasks left:
#   workers decoder eta shots_left errors_seen json_metadata
#       112   bposd <1m       4573        4167 d=6,trial=2
# 1 tasks left:
#   workers decoder eta shots_left errors_seen json_metadata
#       112   bposd <1m       4469        4244 d=6,trial=2
# 1 tasks left:
#   workers decoder eta shots_left errors_seen json_metadata
#       112   bposd <1m       4345        4345 d=6,trial=2
# 1 tasks left:
#   workers decoder eta shots_left errors_seen json_metadata
#       112   bposd <1m       4185        4470 d=6,trial=2
# 1 tasks left:
#   workers decoder eta shots_left errors_seen json_metadata
#       112   bposd <1m       4117        4516 d=6,trial=2
# 1 tasks left:
#   workers decoder eta shots_left errors_seen json_metadata
#       112   bposd <1m       4029        4584 d=6,trial=2
# 1 tasks left:
#   workers decoder eta shots_left errors_seen json_metadata
#       112   bposd <1m       3893        4685 d=6,trial=2
# 1 tasks left:
#   workers decoder eta shots_left errors_seen json_metadata
#       112   bposd <1m       3813        4743 d=6,trial=2
# 1 tasks left:
#   workers decoder eta shots_left errors_seen json_metadata
#       112   bposd <1m       3741        4794 d=6,trial=2
# 1 tasks left:
#   workers decoder eta shots_left errors_seen json_metadata
#       112   bposd <1m       3637        4872 d=6,trial=2
# 1 tasks left:
#   workers decoder eta shots_left errors_seen json_metadata
#       112   bposd <1m       3529        4962 d=6,trial=2
# 1 tasks left:
#   workers decoder eta shots_left errors_seen json_metadata
#       112   bposd <1m       3429        5040 d=6,trial=2
# 1 tasks left:
#   workers decoder eta shots_left errors_seen json_metadata
#       112   bposd <1m       3305        5142 d=6,trial=2
# 1 tasks left:
#   workers decoder eta shots_left errors_seen json_metadata
#       112   bposd <1m       3233        5189 d=6,trial=2
# 1 tasks left:
#   workers decoder eta shots_left errors_seen json_metadata
#       112   bposd <1m       3089        5301 d=6,trial=2
# 1 tasks left:
#   workers decoder eta shots_left errors_seen json_metadata
#       112   bposd <1m       2973        5391 d=6,trial=2
# 1 tasks left:
#   workers decoder eta shots_left errors_seen json_metadata
#       112   bposd <1m       2869        5478 d=6,trial=2
# 1 tasks left:
#   workers decoder eta shots_left errors_seen json_metadata
#       112   bposd <1m       2829        5511 d=6,trial=2
# 1 tasks left:
#   workers decoder eta shots_left errors_seen json_metadata
#       112   bposd <1m       2741        5574 d=6,trial=2
# 1 tasks left:
#   workers decoder eta shots_left errors_seen json_metadata
#       112   bposd <1m       2693        5610 d=6,trial=2
# 1 tasks left:
#   workers decoder eta shots_left errors_seen json_metadata
#       112   bposd <1m       2589        5694 d=6,trial=2
# 1 tasks left:
#   workers decoder eta shots_left errors_seen json_metadata
#       112   bposd <1m       2489        5773 d=6,trial=2
# 1 tasks left:
#   workers decoder eta shots_left errors_seen json_metadata
#       112   bposd <1m       2365        5871 d=6,trial=2
# 1 tasks left:
#   workers decoder eta shots_left errors_seen json_metadata
#       112   bposd <1m       2241        5965 d=6,trial=2
# 1 tasks left:
#   workers decoder eta shots_left errors_seen json_metadata
#       112   bposd <1m       2129        6054 d=6,trial=2
# 1 tasks left:
#   workers decoder eta shots_left errors_seen json_metadata
#       112   bposd <1m       2081        6089 d=6,trial=2
# 1 tasks left:
#   workers decoder eta shots_left errors_seen json_metadata
#       112   bposd <1m       2009        6147 d=6,trial=2
# 1 tasks left:
#   workers decoder eta shots_left errors_seen json_metadata
#       112   bposd <1m       1945        6196 d=6,trial=2
# 1 tasks left:
#   workers decoder eta shots_left errors_seen json_metadata
#       112   bposd <1m       1793        6313 d=6,trial=2
# 1 tasks left:
#   workers decoder eta shots_left errors_seen json_metadata
#       112   bposd <1m       1664        6407 d=6,trial=2
# 1 tasks left:
#   workers decoder eta shots_left errors_seen json_metadata
#       112   bposd <1m       1596        6457 d=6,trial=2
# 1 tasks left:
#   workers decoder eta shots_left errors_seen json_metadata
#       112   bposd <1m       1507        6528 d=6,trial=2
# 1 tasks left:
#   workers decoder eta shots_left errors_seen json_metadata
#       112   bposd <1m       1322        6674 d=6,trial=2
# 1 tasks left:
#   workers decoder eta shots_left errors_seen json_metadata
#       112   bposd <1m       1234        6745 d=6,trial=2
# 1 tasks left:
#   workers decoder eta shots_left errors_seen json_metadata
#       112   bposd <1m       1118        6829 d=6,trial=2
# 1 tasks left:
#   workers decoder eta shots_left errors_seen json_metadata
#       112   bposd <1m       1024        6900 d=6,trial=2
# 1 tasks left:
#   workers decoder eta shots_left errors_seen json_metadata
#       112   bposd <1m        884        7000 d=6,trial=2
# 1 tasks left:
#   workers decoder eta shots_left errors_seen json_metadata
#       112   bposd <1m        802        7062 d=6,trial=2
# 1 tasks left:
#   workers decoder eta shots_left errors_seen json_metadata
#       112   bposd <1m        671        7173 d=6,trial=2
# 1 tasks left:
#   workers decoder eta shots_left errors_seen json_metadata
#       112   bposd <1m        513        7300 d=6,trial=2
# 1 tasks left:
#   workers decoder eta shots_left errors_seen json_metadata
#       112   bposd <1m        268        7497 d=6,trial=2
# 1 tasks left:
#   workers decoder eta shots_left errors_seen json_metadata
#       112   bposd <1m         93        7646 d=6,trial=2
# 1 tasks left:
#   workers decoder eta shots_left errors_seen json_metadata
#       112   bposd <1m         24        7704 d=6,trial=2
# 1 tasks left:
#   workers decoder eta shots_left errors_seen json_metadata
#       112   bposd   ?          0        7727 d=6,trial=2
# Starting 112 workers...
# Stim LER: 0.7727, Sim+Decoding Time: 15.9544424850028s
#
# trial=3
# --- Running Stim for task = 3 ---
# 1 tasks left:
#   workers decoder eta shots_left errors_seen json_metadata
#       112   bposd <1m       9999           1 d=6,trial=3
# 1 tasks left:
#   workers decoder eta shots_left errors_seen json_metadata
#       112   bposd <1m       9988          11 d=6,trial=3
# 1 tasks left:
#   workers decoder eta shots_left errors_seen json_metadata
#       112   bposd <1m       9914          81 d=6,trial=3
# 1 tasks left:
#   workers decoder eta shots_left errors_seen json_metadata
#       112   bposd <1m       9902          91 d=6,trial=3
# 1 tasks left:
#   workers decoder eta shots_left errors_seen json_metadata
#       112   bposd <1m       9884         107 d=6,trial=3
# 1 tasks left:
#   workers decoder eta shots_left errors_seen json_metadata
#       112   bposd <1m       9862         121 d=6,trial=3
# 1 tasks left:
#   workers decoder eta shots_left errors_seen json_metadata
#       112   bposd <1m       9784         185 d=6,trial=3
# 1 tasks left:
#   workers decoder eta shots_left errors_seen json_metadata
#       112   bposd <1m       9600         357 d=6,trial=3
# 1 tasks left:
#   workers decoder eta shots_left errors_seen json_metadata
#       112   bposd <1m       9536         414 d=6,trial=3
# 1 tasks left:
#   workers decoder eta shots_left errors_seen json_metadata
#       112   bposd <1m       9496         447 d=6,trial=3
# 1 tasks left:
#   workers decoder eta shots_left errors_seen json_metadata
#       112   bposd <1m       9436         496 d=6,trial=3
# 1 tasks left:
#   workers decoder eta shots_left errors_seen json_metadata
#       112   bposd <1m       9346         572 d=6,trial=3
# 1 tasks left:
#   workers decoder eta shots_left errors_seen json_metadata
#       112   bposd <1m       9196         700 d=6,trial=3
# 1 tasks left:
#   workers decoder eta shots_left errors_seen json_metadata
#       112   bposd <1m       9117         766 d=6,trial=3
# 1 tasks left:
#   workers decoder eta shots_left errors_seen json_metadata
#       112   bposd <1m       9041         832 d=6,trial=3
# 1 tasks left:
#   workers decoder eta shots_left errors_seen json_metadata
#       112   bposd <1m       9005         864 d=6,trial=3
# 1 tasks left:
#   workers decoder eta shots_left errors_seen json_metadata
#       112   bposd <1m       8931         927 d=6,trial=3
# 1 tasks left:
#   workers decoder eta shots_left errors_seen json_metadata
#       112   bposd <1m       8795        1050 d=6,trial=3
# 1 tasks left:
#   workers decoder eta shots_left errors_seen json_metadata
#       112   bposd <1m       8695        1140 d=6,trial=3
# 1 tasks left:
#   workers decoder eta shots_left errors_seen json_metadata
#       112   bposd <1m       8623        1205 d=6,trial=3
# 1 tasks left:
#   workers decoder eta shots_left errors_seen json_metadata
#       112   bposd <1m       8567        1256 d=6,trial=3
# 1 tasks left:
#   workers decoder eta shots_left errors_seen json_metadata
#       112   bposd <1m       8511        1304 d=6,trial=3
# 1 tasks left:
#   workers decoder eta shots_left errors_seen json_metadata
#       112   bposd <1m       8339        1462 d=6,trial=3
# 1 tasks left:
#   workers decoder eta shots_left errors_seen json_metadata
#       112   bposd <1m       8258        1535 d=6,trial=3
# 1 tasks left:
#   workers decoder eta shots_left errors_seen json_metadata
#       112   bposd <1m       8174        1614 d=6,trial=3
# 1 tasks left:
#   workers decoder eta shots_left errors_seen json_metadata
#       112   bposd <1m       8098        1678 d=6,trial=3
# 1 tasks left:
#   workers decoder eta shots_left errors_seen json_metadata
#       112   bposd <1m       8010        1753 d=6,trial=3
# 1 tasks left:
#   workers decoder eta shots_left errors_seen json_metadata
#       112   bposd <1m       7886        1857 d=6,trial=3
# 1 tasks left:
#   workers decoder eta shots_left errors_seen json_metadata
#       112   bposd <1m       7814        1923 d=6,trial=3
# 1 tasks left:
#   workers decoder eta shots_left errors_seen json_metadata
#       112   bposd <1m       7722        2002 d=6,trial=3
# 1 tasks left:
#   workers decoder eta shots_left errors_seen json_metadata
#       112   bposd <1m       7646        2070 d=6,trial=3
# 1 tasks left:
#   workers decoder eta shots_left errors_seen json_metadata
#       112   bposd <1m       7574        2130 d=6,trial=3
# 1 tasks left:
#   workers decoder eta shots_left errors_seen json_metadata
#       112   bposd <1m       7486        2203 d=6,trial=3
# 1 tasks left:
#   workers decoder eta shots_left errors_seen json_metadata
#       112   bposd <1m       7358        2319 d=6,trial=3
# 1 tasks left:
#   workers decoder eta shots_left errors_seen json_metadata
#       112   bposd <1m       7294        2372 d=6,trial=3
# 1 tasks left:
#   workers decoder eta shots_left errors_seen json_metadata
#       112   bposd <1m       7190        2469 d=6,trial=3
# 1 tasks left:
#   workers decoder eta shots_left errors_seen json_metadata
#       112   bposd <1m       7106        2540 d=6,trial=3
# 1 tasks left:
#   workers decoder eta shots_left errors_seen json_metadata
#       112   bposd <1m       6998        2632 d=6,trial=3
# 1 tasks left:
#   workers decoder eta shots_left errors_seen json_metadata
#       112   bposd <1m       6902        2720 d=6,trial=3
# 1 tasks left:
#   workers decoder eta shots_left errors_seen json_metadata
#       112   bposd <1m       6830        2783 d=6,trial=3
# 1 tasks left:
#   workers decoder eta shots_left errors_seen json_metadata
#       112   bposd <1m       6734        2864 d=6,trial=3
# 1 tasks left:
#   workers decoder eta shots_left errors_seen json_metadata
#       112   bposd <1m       6662        2931 d=6,trial=3
# 1 tasks left:
#   workers decoder eta shots_left errors_seen json_metadata
#       112   bposd <1m       6586        2998 d=6,trial=3
# 1 tasks left:
#   workers decoder eta shots_left errors_seen json_metadata
#       112   bposd <1m       6494        3080 d=6,trial=3
# 1 tasks left:
#   workers decoder eta shots_left errors_seen json_metadata
#       112   bposd <1m       6378        3182 d=6,trial=3
# 1 tasks left:
#   workers decoder eta shots_left errors_seen json_metadata
#       112   bposd <1m       6266        3281 d=6,trial=3
# 1 tasks left:
#   workers decoder eta shots_left errors_seen json_metadata
#       112   bposd <1m       6202        3337 d=6,trial=3
# 1 tasks left:
#   workers decoder eta shots_left errors_seen json_metadata
#       112   bposd <1m       6114        3414 d=6,trial=3
# 1 tasks left:
#   workers decoder eta shots_left errors_seen json_metadata
#       112   bposd <1m       5974        3539 d=6,trial=3
# 1 tasks left:
#   workers decoder eta shots_left errors_seen json_metadata
#       112   bposd <1m       5906        3600 d=6,trial=3
# 1 tasks left:
#   workers decoder eta shots_left errors_seen json_metadata
#       112   bposd <1m       5842        3657 d=6,trial=3
# 1 tasks left:
#   workers decoder eta shots_left errors_seen json_metadata
#       112   bposd <1m       5746        3739 d=6,trial=3
# 1 tasks left:
#   workers decoder eta shots_left errors_seen json_metadata
#       112   bposd <1m       5670        3807 d=6,trial=3
# 1 tasks left:
#   workers decoder eta shots_left errors_seen json_metadata
#       112   bposd <1m       5558        3907 d=6,trial=3
# 1 tasks left:
#   workers decoder eta shots_left errors_seen json_metadata
#       112   bposd <1m       5450        4007 d=6,trial=3
# 1 tasks left:
#   workers decoder eta shots_left errors_seen json_metadata
#       112   bposd <1m       5398        4054 d=6,trial=3
# 1 tasks left:
#   workers decoder eta shots_left errors_seen json_metadata
#       112   bposd <1m       5310        4132 d=6,trial=3
# 1 tasks left:
#   workers decoder eta shots_left errors_seen json_metadata
#       112   bposd <1m       5218        4211 d=6,trial=3
# 1 tasks left:
#   workers decoder eta shots_left errors_seen json_metadata
#       112   bposd <1m       5134        4284 d=6,trial=3
# 1 tasks left:
#   workers decoder eta shots_left errors_seen json_metadata
#       112   bposd <1m       5058        4354 d=6,trial=3
# 1 tasks left:
#   workers decoder eta shots_left errors_seen json_metadata
#       112   bposd <1m       5010        4397 d=6,trial=3
# 1 tasks left:
#   workers decoder eta shots_left errors_seen json_metadata
#       112   bposd <1m       4966        4435 d=6,trial=3
# 1 tasks left:
#   workers decoder eta shots_left errors_seen json_metadata
#       112   bposd <1m       4914        4483 d=6,trial=3
# 1 tasks left:
#   workers decoder eta shots_left errors_seen json_metadata
#       112   bposd <1m       4830        4548 d=6,trial=3
# 1 tasks left:
#   workers decoder eta shots_left errors_seen json_metadata
#       112   bposd <1m       4786        4585 d=6,trial=3
# 1 tasks left:
#   workers decoder eta shots_left errors_seen json_metadata
#       112   bposd <1m       4642        4711 d=6,trial=3
# 1 tasks left:
#   workers decoder eta shots_left errors_seen json_metadata
#       112   bposd <1m       4518        4814 d=6,trial=3
# 1 tasks left:
#   workers decoder eta shots_left errors_seen json_metadata
#       112   bposd <1m       4438        4883 d=6,trial=3
# 1 tasks left:
#   workers decoder eta shots_left errors_seen json_metadata
#       112   bposd <1m       4342        4970 d=6,trial=3
# 1 tasks left:
#   workers decoder eta shots_left errors_seen json_metadata
#       112   bposd <1m       4214        5083 d=6,trial=3
# 1 tasks left:
#   workers decoder eta shots_left errors_seen json_metadata
#       112   bposd <1m       4146        5138 d=6,trial=3
# 1 tasks left:
#   workers decoder eta shots_left errors_seen json_metadata
#       112   bposd <1m       4066        5209 d=6,trial=3
# 1 tasks left:
#   workers decoder eta shots_left errors_seen json_metadata
#       112   bposd <1m       3994        5275 d=6,trial=3
# 1 tasks left:
#   workers decoder eta shots_left errors_seen json_metadata
#       112   bposd <1m       3962        5300 d=6,trial=3
# 1 tasks left:
#   workers decoder eta shots_left errors_seen json_metadata
#       112   bposd <1m       3838        5407 d=6,trial=3
# 1 tasks left:
#   workers decoder eta shots_left errors_seen json_metadata
#       112   bposd <1m       3758        5475 d=6,trial=3
# 1 tasks left:
#   workers decoder eta shots_left errors_seen json_metadata
#       112   bposd <1m       3618        5598 d=6,trial=3
# 1 tasks left:
#   workers decoder eta shots_left errors_seen json_metadata
#       112   bposd <1m       3530        5674 d=6,trial=3
# 1 tasks left:
#   workers decoder eta shots_left errors_seen json_metadata
#       112   bposd <1m       3426        5764 d=6,trial=3
# 1 tasks left:
#   workers decoder eta shots_left errors_seen json_metadata
#       112   bposd <1m       3330        5848 d=6,trial=3
# 1 tasks left:
#   workers decoder eta shots_left errors_seen json_metadata
#       112   bposd <1m       3266        5909 d=6,trial=3
# 1 tasks left:
#   workers decoder eta shots_left errors_seen json_metadata
#       112   bposd <1m       3202        5966 d=6,trial=3
# 1 tasks left:
#   workers decoder eta shots_left errors_seen json_metadata
#       112   bposd <1m       3138        6023 d=6,trial=3
# 1 tasks left:
#   workers decoder eta shots_left errors_seen json_metadata
#       112   bposd <1m       3070        6082 d=6,trial=3
# 1 tasks left:
#   workers decoder eta shots_left errors_seen json_metadata
#       112   bposd <1m       3026        6120 d=6,trial=3
# 1 tasks left:
#   workers decoder eta shots_left errors_seen json_metadata
#       112   bposd <1m       2990        6152 d=6,trial=3
# 1 tasks left:
#   workers decoder eta shots_left errors_seen json_metadata
#       112   bposd <1m       2934        6199 d=6,trial=3
# 1 tasks left:
#   workers decoder eta shots_left errors_seen json_metadata
#       112   bposd <1m       2838        6271 d=6,trial=3
# 1 tasks left:
#   workers decoder eta shots_left errors_seen json_metadata
#       112   bposd <1m       2770        6328 d=6,trial=3
# 1 tasks left:
#   workers decoder eta shots_left errors_seen json_metadata
#       112   bposd <1m       2618        6452 d=6,trial=3
# 1 tasks left:
#   workers decoder eta shots_left errors_seen json_metadata
#       112   bposd <1m       2510        6549 d=6,trial=3
# 1 tasks left:
# ...
#       112   bposd <1m       9669         319 d=6,trial=5
# 1 tasks left:
#   workers decoder eta shots_left errors_seen json_metadata
#       112   bposd <1m       9559         428 d=6,trial=5
# 1 tasks left:
#   workers decoder eta shots_left errors_seen json_metadata
#       112   bposd <1m       9519         468 d=6,trial=5
# 1 tasks left:
#   workers decoder eta shots_left errors_seen json_metadata
#       112   bposd <1m       9489         497 d=6,trial=5
# 1 tasks left:
#   workers decoder eta shots_left errors_seen json_metadata
#       112   bposd <1m       9421         561 d=6,trial=5
# 1 tasks left:
#   workers decoder eta shots_left errors_seen json_metadata
#       112   bposd <1m       9369         612 d=6,trial=5
# 1 tasks left:
#   workers decoder eta shots_left errors_seen json_metadata
#       112   bposd <1m       9201         776 d=6,trial=5
# 1 tasks left:
#   workers decoder eta shots_left errors_seen json_metadata
#       112   bposd <1m       9109         864 d=6,trial=5
# 1 tasks left:
#   workers decoder eta shots_left errors_seen json_metadata
#       112   bposd <1m       9081         891 d=6,trial=5
# 1 tasks left:
#   workers decoder eta shots_left errors_seen json_metadata
#       112   bposd <1m       9040         930 d=6,trial=5
# 1 tasks left:
#   workers decoder eta shots_left errors_seen json_metadata
#       112   bposd <1m       8984         983 d=6,trial=5
# 1 tasks left:
#   workers decoder eta shots_left errors_seen json_metadata
#       112   bposd <1m       8836        1126 d=6,trial=5
# 1 tasks left:
#   workers decoder eta shots_left errors_seen json_metadata
#       112   bposd <1m       8722        1239 d=6,trial=5
# 1 tasks left:
#   workers decoder eta shots_left errors_seen json_metadata
#       112   bposd <1m       8674        1285 d=6,trial=5
# 1 tasks left:
#   workers decoder eta shots_left errors_seen json_metadata
#       112   bposd <1m       8618        1339 d=6,trial=5
# 1 tasks left:
#   workers decoder eta shots_left errors_seen json_metadata
#       112   bposd <1m       8541        1413 d=6,trial=5
# 1 tasks left:
#   workers decoder eta shots_left errors_seen json_metadata
#       112   bposd <1m       8457        1495 d=6,trial=5
# 1 tasks left:
#   workers decoder eta shots_left errors_seen json_metadata
#       112   bposd <1m       8297        1651 d=6,trial=5
# 1 tasks left:
#   workers decoder eta shots_left errors_seen json_metadata
#       112   bposd <1m       8201        1747 d=6,trial=5
# 1 tasks left:
#   workers decoder eta shots_left errors_seen json_metadata
#       112   bposd <1m       8181        1767 d=6,trial=5
# 1 tasks left:
#   workers decoder eta shots_left errors_seen json_metadata
#       112   bposd <1m       8125        1822 d=6,trial=5
# 1 tasks left:
#   workers decoder eta shots_left errors_seen json_metadata
#       112   bposd <1m       8049        1895 d=6,trial=5
# 1 tasks left:
#   workers decoder eta shots_left errors_seen json_metadata
#       112   bposd <1m       7937        2004 d=6,trial=5
# 1 tasks left:
#   workers decoder eta shots_left errors_seen json_metadata
#       112   bposd <1m       7833        2105 d=6,trial=5
# 1 tasks left:
#   workers decoder eta shots_left errors_seen json_metadata
#       112   bposd <1m       7749        2188 d=6,trial=5
# 1 tasks left:
#   workers decoder eta shots_left errors_seen json_metadata
#       112   bposd <1m       7717        2220 d=6,trial=5
# 1 tasks left:
#   workers decoder eta shots_left errors_seen json_metadata
#       112   bposd <1m       7633        2302 d=6,trial=5
# 1 tasks left:
#   workers decoder eta shots_left errors_seen json_metadata
#       112   bposd <1m       7537        2394 d=6,trial=5
# 1 tasks left:
#   workers decoder eta shots_left errors_seen json_metadata
#       112   bposd <1m       7413        2517 d=6,trial=5
# 1 tasks left:
#   workers decoder eta shots_left errors_seen json_metadata
#       112   bposd <1m       7321        2606 d=6,trial=5
# 1 tasks left:
#   workers decoder eta shots_left errors_seen json_metadata
#       112   bposd <1m       7281        2645 d=6,trial=5
# 1 tasks left:
#   workers decoder eta shots_left errors_seen json_metadata
#       112   bposd <1m       7209        2714 d=6,trial=5
# 1 tasks left:
#   workers decoder eta shots_left errors_seen json_metadata
#       112   bposd <1m       7149        2770 d=6,trial=5
# 1 tasks left:
#   workers decoder eta shots_left errors_seen json_metadata
#       112   bposd <1m       7045        2874 d=6,trial=5
# 1 tasks left:
#   workers decoder eta shots_left errors_seen json_metadata
#       112   bposd <1m       6945        2972 d=6,trial=5
# 1 tasks left:
#   workers decoder eta shots_left errors_seen json_metadata
#       112   bposd <1m       6841        3074 d=6,trial=5
# 1 tasks left:
#   workers decoder eta shots_left errors_seen json_metadata
#       112   bposd <1m       6789        3123 d=6,trial=5
# 1 tasks left:
#   workers decoder eta shots_left errors_seen json_metadata
#       112   bposd <1m       6713        3197 d=6,trial=5
# 1 tasks left:
#   workers decoder eta shots_left errors_seen json_metadata
#       112   bposd <1m       6629        3281 d=6,trial=5
# 1 tasks left:
#   workers decoder eta shots_left errors_seen json_metadata
#       112   bposd <1m       6525        3384 d=6,trial=5
# 1 tasks left:
#   workers decoder eta shots_left errors_seen json_metadata
#       112   bposd <1m       6437        3467 d=6,trial=5
# 1 tasks left:
#   workers decoder eta shots_left errors_seen json_metadata
#       112   bposd <1m       6365        3537 d=6,trial=5
# 1 tasks left:
#   workers decoder eta shots_left errors_seen json_metadata
#       112   bposd <1m       6313        3587 d=6,trial=5
# 1 tasks left:
#   workers decoder eta shots_left errors_seen json_metadata
#       112   bposd <1m       6249        3649 d=6,trial=5
# 1 tasks left:
#   workers decoder eta shots_left errors_seen json_metadata
#       112   bposd <1m       6157        3736 d=6,trial=5
# 1 tasks left:
#   workers decoder eta shots_left errors_seen json_metadata
#       112   bposd <1m       6053        3840 d=6,trial=5
# 1 tasks left:
#   workers decoder eta shots_left errors_seen json_metadata
#       112   bposd <1m       5949        3943 d=6,trial=5
# 1 tasks left:
#   workers decoder eta shots_left errors_seen json_metadata
#       112   bposd <1m       5901        3990 d=6,trial=5
# 1 tasks left:
#   workers decoder eta shots_left errors_seen json_metadata
#       112   bposd <1m       5813        4075 d=6,trial=5
# 1 tasks left:
#   workers decoder eta shots_left errors_seen json_metadata
#       112   bposd <1m       5725        4160 d=6,trial=5
# 1 tasks left:
#   workers decoder eta shots_left errors_seen json_metadata
#       112   bposd <1m       5637        4246 d=6,trial=5
# 1 tasks left:
#   workers decoder eta shots_left errors_seen json_metadata
#       112   bposd <1m       5557        4326 d=6,trial=5
# 1 tasks left:
#   workers decoder eta shots_left errors_seen json_metadata
#       112   bposd <1m       5473        4409 d=6,trial=5
# 1 tasks left:
#   workers decoder eta shots_left errors_seen json_metadata
#       112   bposd <1m       5425        4457 d=6,trial=5
# 1 tasks left:
#   workers decoder eta shots_left errors_seen json_metadata
#       112   bposd <1m       5337        4541 d=6,trial=5
# 1 tasks left:
#   workers decoder eta shots_left errors_seen json_metadata
#       112   bposd <1m       5261        4616 d=6,trial=5
# 1 tasks left:
#   workers decoder eta shots_left errors_seen json_metadata
#       112   bposd <1m       5165        4711 d=6,trial=5
# 1 tasks left:
#   workers decoder eta shots_left errors_seen json_metadata
#       112   bposd <1m       5081        4791 d=6,trial=5
# 1 tasks left:
#   workers decoder eta shots_left errors_seen json_metadata
#       112   bposd <1m       5033        4837 d=6,trial=5
# 1 tasks left:
#   workers decoder eta shots_left errors_seen json_metadata
#       112   bposd <1m       4977        4890 d=6,trial=5
# 1 tasks left:
#   workers decoder eta shots_left errors_seen json_metadata
#       112   bposd <1m       4945        4922 d=6,trial=5
# 1 tasks left:
#   workers decoder eta shots_left errors_seen json_metadata
#       112   bposd <1m       4909        4958 d=6,trial=5
# 1 tasks left:
#   workers decoder eta shots_left errors_seen json_metadata
#       112   bposd <1m       4869        4997 d=6,trial=5
# 1 tasks left:
#   workers decoder eta shots_left errors_seen json_metadata
#       112   bposd <1m       4829        5037 d=6,trial=5
# 1 tasks left:
#   workers decoder eta shots_left errors_seen json_metadata
#       112   bposd <1m       4773        5091 d=6,trial=5
# 1 tasks left:
#   workers decoder eta shots_left errors_seen json_metadata
#       112   bposd <1m       4625        5235 d=6,trial=5
# 1 tasks left:
#   workers decoder eta shots_left errors_seen json_metadata
#       112   bposd <1m       4533        5323 d=6,trial=5
# 1 tasks left:
#   workers decoder eta shots_left errors_seen json_metadata
#       112   bposd <1m       4453        5402 d=6,trial=5
# 1 tasks left:
#   workers decoder eta shots_left errors_seen json_metadata
#       112   bposd <1m       4341        5509 d=6,trial=5
# 1 tasks left:
#   workers decoder eta shots_left errors_seen json_metadata
#       112   bposd <1m       4269        5580 d=6,trial=5
# 1 tasks left:
#   workers decoder eta shots_left errors_seen json_metadata
#       112   bposd <1m       4205        5643 d=6,trial=5
# 1 tasks left:
#   workers decoder eta shots_left errors_seen json_metadata
#       112   bposd <1m       4157        5690 d=6,trial=5
# 1 tasks left:
#   workers decoder eta shots_left errors_seen json_metadata
#       112   bposd <1m       4101        5745 d=6,trial=5
# 1 tasks left:
#   workers decoder eta shots_left errors_seen json_metadata
#       112   bposd <1m       4045        5801 d=6,trial=5
# 1 tasks left:
#   workers decoder eta shots_left errors_seen json_metadata
#       112   bposd <1m       3973        5870 d=6,trial=5
# 1 tasks left:
#   workers decoder eta shots_left errors_seen json_metadata
#       112   bposd <1m       3877        5964 d=6,trial=5
# 1 tasks left:
#   workers decoder eta shots_left errors_seen json_metadata
#       112   bposd <1m       3773        6064 d=6,trial=5
# 1 tasks left:
#   workers decoder eta shots_left errors_seen json_metadata
#       112   bposd <1m       3669        6167 d=6,trial=5
# 1 tasks left:
#   workers decoder eta shots_left errors_seen json_metadata
#       112   bposd <1m       3549        6287 d=6,trial=5
# 1 tasks left:
#   workers decoder eta shots_left errors_seen json_metadata
#       112   bposd <1m       3469        6364 d=6,trial=5
# 1 tasks left:
#   workers decoder eta shots_left errors_seen json_metadata
#       112   bposd <1m       3405        6428 d=6,trial=5
# 1 tasks left:
#   workers decoder eta shots_left errors_seen json_metadata
#       112   bposd <1m       3357        6476 d=6,trial=5
# 1 tasks left:
#   workers decoder eta shots_left errors_seen json_metadata
#       112   bposd <1m       3317        6515 d=6,trial=5
# 1 tasks left:
#   workers decoder eta shots_left errors_seen json_metadata
#       112   bposd <1m       3285        6547 d=6,trial=5
# 1 tasks left:
#   workers decoder eta shots_left errors_seen json_metadata
#       112   bposd <1m       3225        6604 d=6,trial=5
# 1 tasks left:
#   workers decoder eta shots_left errors_seen json_metadata
#       112   bposd <1m       3153        6671 d=6,trial=5
# 1 tasks left:
#   workers decoder eta shots_left errors_seen json_metadata
#       112   bposd <1m       3113        6710 d=6,trial=5
# 1 tasks left:
#   workers decoder eta shots_left errors_seen json_metadata
#       112   bposd <1m       3049        6774 d=6,trial=5
# 1 tasks left:
#   workers decoder eta shots_left errors_seen json_metadata
#       112   bposd <1m       2949        6873 d=6,trial=5
# 1 tasks left:
#   workers decoder eta shots_left errors_seen json_metadata
#       112   bposd <1m       2897        6924 d=6,trial=5
# 1 tasks left:
#   workers decoder eta shots_left errors_seen json_metadata
#       112   bposd <1m       2785        7034 d=6,trial=5
# 1 tasks left:
#   workers decoder eta shots_left errors_seen json_metadata
#       112   bposd <1m       2637        7176 d=6,trial=5
# 1 tasks left:
#   workers decoder eta shots_left errors_seen json_metadata
#       112   bposd <1m       2505        7303 d=6,trial=5
# 1 tasks left:
#   workers decoder eta shots_left errors_seen json_metadata
#       112   bposd <1m       2461        7346 d=6,trial=5
# 1 tasks left:
#   workers decoder eta shots_left errors_seen json_metadata
#       112   bposd <1m       2389        7414 d=6,trial=5
# 1 tasks left:
#   workers decoder eta shots_left errors_seen json_metadata
#       112   bposd <1m       2345        7456 d=6,trial=5
# 1 tasks left:
#   workers decoder eta shots_left errors_seen json_metadata
#       112   bposd <1m       2297        7502 d=6,trial=5
# 1 tasks left:
#   workers decoder eta shots_left errors_seen json_metadata
#       112   bposd <1m       2249        7550 d=6,trial=5
# 1 tasks left:
#   workers decoder eta shots_left errors_seen json_metadata
#       112   bposd <1m       2225        7571 d=6,trial=5
# 1 tasks left:
#   workers decoder eta shots_left errors_seen json_metadata
#       112   bposd <1m       2189        7606 d=6,trial=5
# 1 tasks left:
#   workers decoder eta shots_left errors_seen json_metadata
#       112   bposd <1m       2141        7654 d=6,trial=5
# 1 tasks left:
#   workers decoder eta shots_left errors_seen json_metadata
#       112   bposd <1m       2049        7744 d=6,trial=5
# 1 tasks left:
#   workers decoder eta shots_left errors_seen json_metadata
#       112   bposd <1m       2000        7793 d=6,trial=5
# 1 tasks left:
#   workers decoder eta shots_left errors_seen json_metadata
#       112   bposd <1m       1884        7907 d=6,trial=5
# 1 tasks left:
#   workers decoder eta shots_left errors_seen json_metadata
#       112   bposd <1m       1763        8024 d=6,trial=5
# 1 tasks left:
#   workers decoder eta shots_left errors_seen json_metadata
#       112   bposd <1m       1662        8122 d=6,trial=5
# 1 tasks left:
#   workers decoder eta shots_left errors_seen json_metadata
#       112   bposd <1m       1598        8183 d=6,trial=5
# 1 tasks left:
#   workers decoder eta shots_left errors_seen json_metadata
#       112   bposd <1m       1407        8371 d=6,trial=5
# 1 tasks left:
#   workers decoder eta shots_left errors_seen json_metadata
#       112   bposd <1m       1309        8466 d=6,trial=5
# 1 tasks left:
#   workers decoder eta shots_left errors_seen json_metadata
#       112   bposd <1m       1173        8599 d=6,trial=5
# 1 tasks left:
#   workers decoder eta shots_left errors_seen json_metadata
#       112   bposd <1m       1071        8698 d=6,trial=5
# 1 tasks left:
#   workers decoder eta shots_left errors_seen json_metadata
#       112   bposd <1m       1035        8732 d=6,trial=5
# 1 tasks left:
#   workers decoder eta shots_left errors_seen json_metadata
#       112   bposd <1m        956        8810 d=6,trial=5
# 1 tasks left:
#   workers decoder eta shots_left errors_seen json_metadata
#       112   bposd <1m        855        8907 d=6,trial=5
# 1 tasks left:
#   workers decoder eta shots_left errors_seen json_metadata
#       112   bposd <1m        703        9056 d=6,trial=5
# 1 tasks left:
#   workers decoder eta shots_left errors_seen json_metadata
#       112   bposd <1m        498        9253 d=6,trial=5
# 1 tasks left:
#   workers decoder eta shots_left errors_seen json_metadata
#       112   bposd <1m        239        9502 d=6,trial=5
# 1 tasks left:
#   workers decoder eta shots_left errors_seen json_metadata
#       112   bposd <1m         95        9645 d=6,trial=5
# 1 tasks left:
#   workers decoder eta shots_left errors_seen json_metadata
#       112   bposd <1m         11        9728 d=6,trial=5
# 1 tasks left:
#   workers decoder eta shots_left errors_seen json_metadata
#       112   bposd   ?          0        9739 d=6,trial=5
# Stim LER: 0.9739, Sim+Decoding Time: 15.06753087695688s
#
#
# Stim complete.
# Stim LERs: [0.5578, 0.6351, 0.7727, 0.8746, 0.937, 0.9739]
# Saved Stim (BP+OSD) results to ./bposd_72_results/stim_bposd_results_d6_shots10000.txt

# %%
from concurrent.futures import ProcessPoolExecutor
import bposd_mp

def run_cpp_experiment(tasks, shots):
    cpp_lers = []
    for i, task in enumerate(tasks):
        d = task.json_metadata.get('d')
        print(f"\n--- Running C++ (MPI) for p = {i} ---")

        # Paths
        qasm_file_path = os.path.join(qasm_dir, f"bb_code_d{d}_p{i}.qasm")
        cpp_output_path = os.path.join(qasm_dir, f"measurements_d{d}_p{i}.txt")

        # MPI execution
        num_qubits = task.circuit.num_qubits
        mpi_ranks = os.cpu_count()//4  # don't spawn more ranks than shots
        iters = shots

        # env = os.environ.copy()
        # env.update({
        #     "OMP_NUM_THREADS": "1",
        #     "OPENBLAS_NUM_THREADS": "1",
        #     "MKL_NUM_THREADS": "1",
        #     "VECLIB_MAXIMUM_THREADS": "1",
        #     "NUMEXPR_NUM_THREADS": "1",
        # })

        run_command = [
            "mpirun", "-np", str(mpi_ranks),
            "./bb_code_sim", str(num_qubits), str(iters), qasm_file_path, cpp_output_path
        ]

        cpp_time = 0
        try:
            result = subprocess.run(run_command, check=True, capture_output=True, text=True)
            for line in result.stdout.strip().split('\n'):
                if "Total C++ simulation time" in line:
                    try:
                        cpp_time = float(line.split(':')[1].strip().replace('s', ''))
                    except (ValueError, IndexError):
                        pass
        except subprocess.CalledProcessError as e:
            print("C++ simulation failed to execute.")
            print("Return code:", e.returncode)
            print("--- stdout ---")
            print(e.stdout)
            print("--- stderr ---")
            print(e.stderr)
            continue

        # Post-process + parallel BPOSD decoding
        print(f"\n--- BPOSD Decoding ---")
        cpp_ler = 0
        try:
            with open(cpp_output_path, "r") as f:
                measurement_strings = [line for line in f.read().strip().split('\n') if line]

            if measurement_strings:
                measurement_data = np.array(
                    [list(map(int, line.split())) for line in measurement_strings],
                    dtype=np.int8
                ).astype(bool)

                m2d_converter = task.circuit.compile_m2d_converter()
                cpp_det_samples, cpp_obs_flips = m2d_converter.convert(
                    measurements=measurement_data,
                    separate_observables=True
                )

                dem = task.circuit.detector_error_model(
                    decompose_errors=True,
                    ignore_decomposition_failures=True
                )

                from beliefmatching import detector_error_model_to_check_matrices
                pcm = detector_error_model_to_check_matrices(dem, allow_undecomposed_hyperedges=True)

                logicals_matrix = pcm.observables_matrix
                decoder_kwargs = dict(
                    max_iter=1_000,
                    bp_method="ms",
                    osd_order=10,
                    osd_method="osd_e",
                )

                total_shots = len(cpp_det_samples)
                if total_shots > 0:
                    import math
                    num_decode_workers = os.cpu_count()//3

                    # Simplified chunking: give each worker a single chunk of tasks
                    chunk_size = math.ceil(total_shots / num_decode_workers)
                    if chunk_size > 0:
                        det_chunks = [cpp_det_samples[i:i + chunk_size] for i in range(0, total_shots, chunk_size)]
                        obs_chunks = [cpp_obs_flips[i:i + chunk_size] for i in range(0, total_shots, chunk_size)]
                    else:
                        det_chunks, obs_chunks = [], []


                    # Use a process pool to run decoding in parallel, bypassing the GIL.
                    # The worker_init function pre-loads each worker process with the large,
                    # shared data (check matrix, priors) to avoid costly serialization.
                    with ProcessPoolExecutor(
                        max_workers=num_decode_workers,
                        initializer=bposd_mp.worker_init,
                        initargs=(pcm.check_matrix, pcm.priors, logicals_matrix, decoder_kwargs),
                    ) as executor:
                        # Map the count_errors function over the chunks of data.
                        # The sum of errors from all chunks gives the total.
                        total_errors = sum(executor.map(bposd_mp.count_errors, det_chunks, obs_chunks))

                    cpp_ler = float(total_errors) / float(total_shots)
                else:
                    cpp_ler = 0.0

        except FileNotFoundError:
            print(f"C++ output file not found at {cpp_output_path}. Skipping analysis.")

        cpp_lers.append(cpp_ler)
        print(f"C++ LER: {cpp_ler}, Sim Time: {cpp_time}s")
    return cpp_lers

# --- Run C++-only experiment ---
# reuse SHOTS from previous cell
cpp_logical_error_rates = run_cpp_experiment(tasks, SHOTS)
print("\nC++ complete.")
print("C++ LERs:", cpp_logical_error_rates)
# ...existing code...

try:
    results_dir = "./bposd_72_results"
    os.makedirs(results_dir, exist_ok=True)
    p_amp_arr = 1 - np.exp(-tau / T1)
    lam = 1 / T2 - 1 / (2 * T1)
    p_phase_arr = 1 - np.exp(-lam * tau)
    cpp_results_path = os.path.join(results_dir, f"cpp_bposd_results_d{distance}_shots{SHOTS}.txt")
    with open(cpp_results_path, "w") as f:
        f.write("# tau\tp_amp\tp_phase\tcpp_ler\n")
        for ta, pa, pp, ler in zip(tau, p_amp_arr, p_phase_arr, cpp_logical_error_rates):
            f.write(f"{ta}\t{pa}\t{pp}\t{ler}\n")
    print(f"Saved C++ (BP+OSD) results to {cpp_results_path}")
except Exception as e:
    print("Failed to save C++ results:", e)
# Out:
# --- Running C++ (MPI) for p = 0 ---
#
# --- BPOSD Decoding ---
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[32], line 125
#     121     return cpp_lers
#     123 # --- Run C++-only experiment ---
#     124 # reuse SHOTS from previous cell
# --> 125 cpp_logical_error_rates = run_cpp_experiment(tasks, SHOTS)
#     126 print("\nC++ complete.")
#     127 print("C++ LERs:", cpp_logical_error_rates)
#
# Cell In[32], line 59, in run_cpp_experiment(tasks, shots)
#      56     measurement_strings = [line for line in f.read().strip().split('\n') if line]
#      58 if measurement_strings:
# ---> 59     measurement_data = np.array(
#      60         [list(map(int, line.split())) for line in measurement_strings],
#      61         dtype=np.int8
#      62     ).astype(bool)
#      64     m2d_converter = task.circuit.compile_m2d_converter()
#      65     cpp_det_samples, cpp_obs_flips = m2d_converter.convert(
#      66         measurements=measurement_data,
#      67         separate_observables=True
#      68     )
#
# ValueError: setting an array element with a sequence. The requested array has an inhomogeneous shape after 1 dimensions. The detected shape was (5004616,) + inhomogeneous part.

# %%
import os, sys, importlib
qasm_dir = "./bb_code_72_qasm"
os.makedirs(qasm_dir, exist_ok=True)

# New: directory for saved results
results_dir = "./results_72_"
os.makedirs(results_dir, exist_ok=True)

# Make sure we can import the conversion utilities
sys.path.insert(0, os.path.abspath("../../../src"))

# %%
# --- Plotting Results ---
plt.figure(figsize=(8, 6))

plt.plot(tau/T1, stim_logical_error_rates, 'o-', label='Stim LER (BP+OSD)')
plt.plot(tau/T1, cpp_logical_error_rates, 's--', label='C++ LER (BP+OSD)')
plt.xlabel("Physical Error Rate (p)")
plt.ylabel("Logical Error Rate (LER)")
plt.title(f"LER vs. Physical Error Rate for BB Code (d={distance}) Shots= {SHOTS}")
plt.xscale('log')
plt.yscale('log')
plt.grid(True, which="both", ls="--")
plt.legend()
plt.tight_layout()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from pathlib import Path

# --- Reload and plot previously saved results ---

# Ensure these parameters match the saved files you want to load
SHOTS = 2000000
distance = 6
T1 = 10**-4
T2 = 10**-4

results_dir = "./bposd_72_results"
stim_results_path = Path(results_dir) / f"stim_bposd_results_d{distance}_shots{SHOTS}.txt"
cpp_results_path = Path(results_dir) / f"cpp_bposd_results_d{distance}_shots{SHOTS}.txt"

# Check if files exist
if not stim_results_path.exists() or not cpp_results_path.exists():
    missing = []
    if not stim_results_path.exists(): missing.append(str(stim_results_path))
    if not cpp_results_path.exists(): missing.append(str(cpp_results_path))
    raise FileNotFoundError("Missing results files: " + ", ".join(missing))

# Function to load data from a tab-separated file
def load_results(path):
    data = np.loadtxt(path, comments='#', delimiter='\t')
    # Assuming columns are: tau, p_amp, p_phase, ler
    return data[:, 0], data[:, 3]

# Load data
tau_s, stim_ler_s = load_results(stim_results_path)
tau_c, cpp_ler_c = load_results(cpp_results_path)

# --- Plotting ---
plt.figure(figsize=(8, 6))
plt.plot(tau_s / T1, stim_ler_s, 'o-', label='Stim LER (BP+OSD) [loaded]')
plt.plot(tau_c / T1, cpp_ler_c, 's--', label='C++ LER (BP+OSD) [loaded]')

plt.xlabel(r"$\tau / T1$ Ratio")
plt.ylabel("Logical Error Rate (LER)")
plt.title(f"Loaded LER for BB Code (d={distance}), Shots={SHOTS}")
plt.xscale('log')
plt.yscale('log')
plt.grid(True, which="both", ls="--")
plt.legend()
plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[1], line 22
#      20     if not stim_results_path.exists(): missing.append(str(stim_results_path))
#      21     if not cpp_results_path.exists(): missing.append(str(cpp_results_path))
# ---> 22     raise FileNotFoundError("Missing results files: " + ", ".join(missing))
#      24 # Function to load data from a tab-separated file
#      25 def load_results(path):
#
# FileNotFoundError: Missing results files: bposd_72_results/stim_bposd_results_d6_shots2000000.txt, bposd_72_results/cpp_bposd_results_d6_shots2000000.txt
